# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
data_path= "./images/dc.jpg"

# %% [markdown]
# ##**1. Load and Display an Image**

# %%
import cv2
img = cv2.imread(data_path)
cv2.imshow("Original Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##**2. Convert Color (BGR ↔ Grayscale, HSV)**

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGRA2RGBA)
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)


cv2.imshow("Gray Image", gray)
cv2.imshow("HSV Image", hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##**3. Resize an Image Keeping Aspect Ratio**

# %%
# covered below

# %% [markdown]
# ##**Load and Display Images in Different Modes**

# %%
# Load in different modes
color = cv2.imread(data_path, cv2.IMREAD_COLOR)
gray = cv2.imread(data_path, cv2.IMREAD_GRAYSCALE)
unchanged = cv2.imread(data_path, cv2.IMREAD_UNCHANGED)

# Display
cv2.imshow("Color", color)
cv2.imshow("Grayscale", gray)
cv2.imshow("Unchanged (with Alpha)", unchanged)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##**Save the Images to Disk**

# %%
cv2.imwrite("saved_color.jpg", color)
cv2.imwrite("saved_gray.jpg", gray)
cv2.imwrite("saved_unchanged.png", unchanged)
# Out:
# True

# %% [markdown]
# ## Image Resizing, Cropping, and Flipping

# %%
# Load the image
image = cv2.imread(data_path)  # Replace with your image path
cv2.imshow("Original Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# -------------------------
# 1. Resize the image
# -------------------------
resized = cv2.resize(image, (500, 500))  # Resize to 400x300
cv2.imshow("Resized Image (400x300)", resized)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# -------------------------
# 2. Crop the image
# -------------------------



# Get image dimensions
height, width = image.shape[:2]

# Crop the region: image[y1:y2, x1:x2]
# Example: Crop the top-left 100x100 region
cropped = image[100:200, 100:200]

# Display the cropped image
cv2.imshow("Cropped Image", cropped)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# -------------------------
# 3. Flip the image
# -------------------------
flip_horizontal = cv2.flip(image, 1)  # 1 = horizontal flip
flip_vertical = cv2.flip(image, 0)    # 0 = vertical flip
flip_both = cv2.flip(image, -1)       # -1 = both axes

cv2.imshow("Flipped Horizontally", flip_horizontal)
cv2.imshow("Flipped Vertically", flip_vertical)
cv2.imshow("Flipped Both", flip_both)

# Wait until a key is pressed and close windows
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## **DRAWING ON IMAGES**

# %%
# 1. Import required libraries
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Utility function to display image in Jupyter
def show_img(img, title="Image", cmap_type=None):
    plt.figure(figsize=(6, 4))
    if cmap_type:
        plt.imshow(img, cmap=cmap_type)
    else:
        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        plt.imshow(img_rgb)
    plt.title(title)
    plt.axis("off")
    plt.show()

# %% [markdown]
# Create a blank image (black canvas)

# %%
# 2. Create a blank image (black canvas)
blank_img = np.zeros((400, 600, 3), dtype=np.uint8)
show_img(blank_img, "Blank Canvas")

# %%
# 3. Draw a green line
cv2.line(blank_img, (50, 50), (550, 50), color=(0, 255, 0), thickness=3)
show_img(blank_img, "Line Drawn")

# %%
# 4. Draw a blue rectangle
cv2.rectangle(blank_img, (100, 100), (500, 250), color=(255, 0, 0), thickness=2)
show_img(blank_img, "Rectangle Drawn")

# %% [markdown]
# thickness = 1: draws a thin outline of 1 pixel.
#
# thickness = 5: draws a thicker outline.
#
# thickness = -1: draws a filled shape.

# %%
# 5. Draw a red filled circle
cv2.circle(blank_img, center=(300, 175), radius=40, color=(0, 0, 255), thickness=-1)
show_img(blank_img, "Circle Drawn")

# %%
# cv2.ellipse(
#     img=blank_img,           # Image to draw on
#     center=(300, 300),       # Center of the ellipse
#     axes=(100, 50),          # Length of major (100) and minor (50) axes
#     angle=0,                 # Rotation of the ellipse in degrees (here, no rotation)
#     startAngle=0,            # Starting angle of the arc (in degrees)
#     endAngle=180,            # Ending angle of the arc (in degrees)
#     color=(255, 255, 0),     # Color (cyan in BGR)
#     thickness=2              # Thickness of the outline (2 pixels)
# )

# %%
# 6. Draw an ellipse
cv2.ellipse(blank_img, (300, 300), (100, 50), 0, 0, 180, (255, 255, 0), 2)
show_img(blank_img, "Ellipse Drawn")

# %%
# cv2.putText(
#     blank_img,                # Image on which to write text
#     "OpenCV Rocks!",          # Text string to be drawn
#     (150, 370),               # Bottom-left corner of the text in the image (x=150, y=370)
#     cv2.FONT_HERSHEY_SIMPLEX, # Font type
#     1,                        # Font scale (size multiplier)
#     (255, 255, 255),          # Color in BGR (white in this case)
#     2                         # Thickness of the text strokes
# )

# %%
# 7. Put text on the image
cv2.putText(blank_img, "OpenCV Rocks!", (150, 370), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
show_img(blank_img, "Text Added")

# %%
#  Load a real image
real_img = cv2.imread(data_path)  # Replace with your local image
if real_img is not None:
    show_img(real_img, "Original Image")
else:
    print("Image not found. Please ensure 'sample.jpg' exists in the same directory.")

# %%
# Annotate real image with bounding box and label
if real_img is not None:
    annotated_img = real_img.copy()
    cv2.rectangle(annotated_img, (50, 50), (250, 250), (0, 255, 0), 2)
    cv2.putText(annotated_img, "Object", (50, 45), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
    show_img(annotated_img, "Annotated Image")
