# %% [markdown]
# ### **Installation Guide**
#
# #### **1. Install Docker**
# Docker is required to run Open WebUI in a containerized environment.
# - **Windows & macOS**: Download and install **Docker Desktop** from [Docker's official website](https://www.docker.com/products/docker-desktop/).
# - **Linux (Debian/Ubuntu-based)**: Run the following commands:
#   ```sh
#   sudo apt update
#   sudo apt install -y docker.io
#   sudo systemctl enable --now docker
#   ```
#   To verify the installation:
#   ```sh
#   docker --version
#   ```
#
# #### **2. Install Ollama**
# Ollama is used to run local LLMs efficiently.
# - **macOS (via Homebrew):**
#   ```sh
#   brew install ollama
#   ```
# - **Windows:** Download and install it from [Ollama’s website](https://ollama.com/download).
# - **Linux:** Run the following command:
#   ```sh
#   curl -fsSL https://ollama.com/install.sh | sh
#   ```
#   Verify the installation:
#   ```sh
#   ollama --version
#   ```
#
# #### **3. Install Open WebUI**
# Once Docker is installed, run the following command to set up Open WebUI:
# ```sh
# docker run -d -p 3000:8080 --add-host=host.docker.internal:host-gateway \
# -v open-webui:/app/backend/data --name open-webui --restart always \
# ghcr.io/open-webui/open-webui:main
# ```
# This command will:
# ✅ Run Open WebUI in **detached mode (`-d`)**.
# ✅ Map port **3000 on the host** to **8080 inside the container**.
# ✅ Mount a volume (`open-webui`) for persistent data.
# ✅ Restart automatically on failure.
#
# #### **4. Access Open WebUI & Create a User**
# - Once the container is running, open your browser and go to:
#   🔗 **http://localhost:3000**
# - The first time you access Open WebUI, you will be prompted to **create a user account**.
# - Enter your **email, username, and password** to complete the setup.
# - After account creation, log in and start using Open WebUI!
