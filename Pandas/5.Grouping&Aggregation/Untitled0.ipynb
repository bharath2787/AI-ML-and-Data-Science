# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the students dataset
df = pd.read_csv('/content/drive/MyDrive/0.Latest_DS_Course/Pandas/Data/Students.csv')
# Display the first few rows of the dataset
df.head(10)
# Out:
#         Name    Grade  Age  Gender  Score
# 0   Student1  Grade 8   14    Male     85
# 1   Student2  Grade 7   13  Female     92
# 2   Student3  Grade 9   15    Male     78
# 3   Student4  Grade 6   12  Female     95
# 4   Student5  Grade 8   14    Male     89
# 5   Student6  Grade 7   13  Female     88
# 6   Student7  Grade 9   15    Male     76
# 7   Student8  Grade 6   12  Female     94
# 8   Student9  Grade 8   14    Male     87
# 9  Student10  Grade 7   13  Female     91

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df["Grade"].unique()
# Out:
# array(['Grade 8', 'Grade 7', 'Grade 9', 'Grade 6'], dtype=object)

# %%
df['Grade'].nunique()
# Out:
# 4

# %%
Grade_groups = df.groupby("Grade")

# %%
Grade_groups.groups
# Out:
# {'Grade 6': [3, 7, 11, 15, 19], 'Grade 7': [1, 5, 9, 13, 17], 'Grade 8': [0, 4, 8, 12, 16], 'Grade 9': [2, 6, 10, 14, 18]}

# %%
df
# Out:
#          Name    Grade  Age  Gender  Score
# 0    Student1  Grade 8   14    Male     85
# 1    Student2  Grade 7   13  Female     92
# 2    Student3  Grade 9   15    Male     78
# 3    Student4  Grade 6   12  Female     95
# 4    Student5  Grade 8   14    Male     89
# 5    Student6  Grade 7   13  Female     88
# 6    Student7  Grade 9   15    Male     76
# 7    Student8  Grade 6   12  Female     94
# 8    Student9  Grade 8   14    Male     87
# 9   Student10  Grade 7   13  Female     91
# 10  Student11  Grade 9   15    Male     75
# 11  Student12  Grade 6   12  Female     96
# 12  Student13  Grade 8   14    Male     88
# 13  Student14  Grade 7   13  Female     90
# 14  Student15  Grade 9   15    Male     77
# 15  Student16  Grade 6   12  Female     93
# 16  Student17  Grade 8   14    Male     86
# 17  Student18  Grade 7   13  Female     89
# 18  Student19  Grade 9   15    Male     74
# 19  Student20  Grade 6   12  Female     97

# %%
for name, value in Grade_groups:
  print(name)
  # display(value)
# Out:
# Grade 6
# Grade 7
# Grade 8
# Grade 9

# %%
type(Grade_groups)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
Grade_groups.get_group("Grade 7")
# Out:
#          Name    Grade  Age  Gender  Score
# 1    Student2  Grade 7   13  Female     92
# 5    Student6  Grade 7   13  Female     88
# 9   Student10  Grade 7   13  Female     91
# 13  Student14  Grade 7   13  Female     90
# 17  Student18  Grade 7   13  Female     89

# %%
Grade_groups.size()
# Out:
# Grade
# Grade 6    5
# Grade 7    5
# Grade 8    5
# Grade 9    5
# dtype: int64

# %%
Grade_groups.count()
# Out:
#          Name  Age  Gender  Score
# Grade
# Grade 6     5    5       5      5
# Grade 7     5    5       5      5
# Grade 8     5    5       5      5
# Grade 9     5    5       5      5

# %%
df['Grade'].value_counts()
# Out:
# Grade
# Grade 8    5
# Grade 7    5
# Grade 9    5
# Grade 6    5
# Name: count, dtype: int64

# %%
#find the toppper of grade 9

# %%
df['Grade']=="Grade 9"
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# Name: Grade, dtype: bool

# %%
Grade9_df = df[df['Grade']=="Grade 9"]

# %%
Grade9_df
# Out:
#          Name    Grade  Age Gender  Score
# 2    Student3  Grade 9   15   Male     78
# 6    Student7  Grade 9   15   Male     76
# 10  Student11  Grade 9   15   Male     75
# 14  Student15  Grade 9   15   Male     77
# 18  Student19  Grade 9   15   Male     74

# %%
Grade9_df.sort_values(by="Score", ascending=False).head(1)["Name"]
# Out:
# 2    Student3
# Name: Name, dtype: object

# %%
Grade9_df[Grade9_df['Score']==Grade9_df['Score'].max()]
# Out:
#        Name    Grade  Age Gender  Score
# 2  Student3  Grade 9   15   Male     78

# %%
Grade9_df
# Out:
#          Name    Grade  Age Gender  Score
# 2    Student3  Grade 9   15   Male     78
# 6    Student7  Grade 9   15   Male     76
# 10  Student11  Grade 9   15   Male     75
# 14  Student15  Grade 9   15   Male     77
# 18  Student19  Grade 9   15   Male     74

# %%
Grade9_df.nlargest(1,"Score")
# Out:
#        Name    Grade  Age Gender  Score
# 2  Student3  Grade 9   15   Male     78

# %%
# find the topper of all grades

# %%
df
# Out:
#          Name    Grade  Age  Gender  Score
# 0    Student1  Grade 8   14    Male     85
# 1    Student2  Grade 7   13  Female     92
# 2    Student3  Grade 9   15    Male     78
# 3    Student4  Grade 6   12  Female     95
# 4    Student5  Grade 8   14    Male     89
# 5    Student6  Grade 7   13  Female     88
# 6    Student7  Grade 9   15    Male     76
# 7    Student8  Grade 6   12  Female     94
# 8    Student9  Grade 8   14    Male     87
# 9   Student10  Grade 7   13  Female     91
# 10  Student11  Grade 9   15    Male     75
# 11  Student12  Grade 6   12  Female     96
# 12  Student13  Grade 8   14    Male     88
# 13  Student14  Grade 7   13  Female     90
# 14  Student15  Grade 9   15    Male     77
# 15  Student16  Grade 6   12  Female     93
# 16  Student17  Grade 8   14    Male     86
# 17  Student18  Grade 7   13  Female     89
# 18  Student19  Grade 9   15    Male     74
# 19  Student20  Grade 6   12  Female     97

# %%
df.nlargest(1, "Score")["Name"]
# Out:
# 19    Student20
# Name: Name, dtype: object

# %%
df.sort_values(by="Score", ascending=False).head(1)
# Out:
#          Name    Grade  Age  Gender  Score
# 19  Student20  Grade 6   12  Female     97

# %%
df[df['Score']==df['Score'].max()]
# Out:
#          Name    Grade  Age  Gender  Score
# 19  Student20  Grade 6   12  Female     97

# %%
df['Score'].mean()
# Out:
# 87.0

# %%
movies = pd.read_csv('/content/drive/MyDrive/0.Latest_DS_Course/Pandas/Data/imdb-top-1000.csv')

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
movies['Genre'].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %%
movies['Genre'].nunique()
# Out:
# 14

# %%
movies.groupby("Genre").size().sort_values(ascending=False)
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Family         2
# Fantasy        2
# Thriller       1
# dtype: int64

# %%
movies.groupby("Genre").count()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172            172      172          172       172    172
# Adventure            72             72       72           72        72     72
# Animation            82             82       82           82        82     82
# Biography            88             88       88           88        88     88
# Comedy              155            155      155          155       155    155
# Crime               107            107      107          107       107    107
# Drama               289            289      289          289       289    289
# Family                2              2        2            2         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       11           11        11     11
# ...

# %%
movies['Genre'].value_counts()
# Out:
# Genre
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: count, dtype: int64

# %%
genre = movies.groupby("Genre")

# %%
genre.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %%
genre.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
lst = ["2000", "Abcd","Zasdf"]

# %%
df = pd.DataFrame(lst, columns=["TEST"])

# %%
df
# Out:
#     TEST
# 0   2000
# 1   Abcd
# 2  Zasdf

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TEST    3 non-null      object
# dtypes: object(1)
# memory usage: 156.0+ bytes

# %%
df['TEST'].max()
# Out:
# 'Zasdf'

# %%
df['TEST'].min()
# Out:
# '2000'

# %%
movies.groupby("Genre")["Gross"].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby("Genre").sum()["Gross"].sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
movies.groupby("Genre")["No_of_Votes"].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Action    72282412
# Drama     61367304
# Crime     33533615
# Name: No_of_Votes, dtype: int64

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
lst = [1,2,3]

# %%
df =pd.DataFrame(lst, columns=["abcd"])

# %%
df["abcd"].sum()
# Out:
# 6

# %%
# genre > hightest> avg> IMBD RAting

# %%
movies.groupby("Genre")["IMDB_Rating"].mean().sort_values(ascending=False).head(2)
# Out:
# Genre
# Western    8.350000
# Crime      8.016822
# Name: IMDB_Rating, dtype: float64

# %%
# movie with the highest rating

# %%
movies.nlargest(1, "IMDB_Rating")
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
movies[movies["IMDB_Rating"]==movies["IMDB_Rating"].max()]
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
movies.sort_values(by="IMDB_Rating", ascending=False).head(1)
# Out:
#                Series_Title Released_Year  Runtime  Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          Director        Star1  No_of_Votes       Gross  Metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
movies[movies['IMDB_Rating'] ==  8]
# Out:
#                        Series_Title Released_Year  Runtime      Genre  \
# 322                      Badhaai ho          2018      124     Comedy
# 323                            Togo          2019      113  Adventure
# 324                         Airlift          2016      130      Drama
# 325               Bajrangi Bhaijaan          2015      163     Action
# 326                            Baby          2015      159     Action
# ..                              ...           ...      ...        ...
# 458                The Wizard of Oz          1939      102  Adventure
# 459                 La règle du jeu          1939      110     Comedy
# 460                    The Thin Man          1934       91     Comedy
# 461  All Quiet on the Western Front          1930      152      Drama
# 462            Bronenosets Potemkin          1925       75      Drama
#
#      IMDB_Rating                  Director               Star1  No_of_Votes  \
# ...

# %%
movies['IMDB_Rating'].unique()
# Out:
# array([9.3, 9.2, 9. , 8.9, 8.8, 8.7, 8.6, 8.5, 8.4, 8.3, 8.2, 8.1, 8. ,
#        7.9, 7.8, 7.7, 7.6])

# %%
# find the most popular director across the entire dataset

# %%
movies.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
# average gross

# %%
movies.groupby("Director").size().sort_values(ascending=False)
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
#                     ..
# Jessie Nelson        1
# Jeong-beom Lee       1
# Jemaine Clement      1
# Jeethu Joseph        1
# Ömer Faruk Sorak     1
# Length: 548, dtype: int64

# %%
movies['Director'].value_counts()
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
#                     ..
# Neill Blomkamp       1
# Tomas Alfredson      1
# Duncan Jones         1
# Jacques Audiard      1
# George Stevens       1
# Name: count, Length: 548, dtype: int64

# %%
movies.groupby("Director")['Gross'].mean().sort_values(ascending=False).head(3)
# Out:
# Director
# Ramesh Sippy     932069480.0
# Dennis Gansel    924558264.0
# Arthur Penn      909838190.0
# Name: Gross, dtype: float64

# %%
movies.groupby("Director")['Gross'].max().sort_values(ascending=False).head(3)
# Out:
# Director
# J.J. Abrams      936662225.0
# Ramesh Sippy     932069480.0
# Dennis Gansel    924558264.0
# Name: Gross, dtype: float64

# %%
movies.groupby("Director")['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Akira Kurosawa      3.070432e+09
# Steven Spielberg    2.478133e+09
# Hayao Miyazaki      2.447325e+09
# Name: Gross, dtype: float64

# %%
movies.groupby("Director")['No_of_Votes'].sum().sort_values(ascending=False).head(3)
# Out:
# Director
# Christopher Nolan    11578345
# Quentin Tarantino     8123208
# Steven Spielberg      7817166
# Name: No_of_Votes, dtype: int64

# %%
movies.groupby("Director").agg({
    "No_of_Votes" : "sum",
    "Gross" : "sum"

}).sort_values(by= ["No_of_Votes", "Gross"])
# Out:
#                    No_of_Votes         Gross
# Director
# Kaige Chen               25088  5.216888e+06
# Francis Lee              25198  3.356090e+05
# René Laloux              25229  1.938170e+05
# Peter Mullan             25938  4.890878e+06
# J. Lee Thompson          26457  8.633920e+08
# ...                        ...           ...
# Martin Scorsese        6513530  5.383192e+08
# David Fincher          6607859  7.133145e+08
# Steven Spielberg       7817166  2.478133e+09
# Quentin Tarantino      8123208  7.270343e+08
# Christopher Nolan     11578345  1.937454e+09
#
# [548 rows x 2 columns]

# %%
# most popular director in each genre

# %%
movies.groupby("Genre")['Gross'].max().sort_values(ascending=False)
# Out:
# Genre
# Action       936662225.0
# Drama        924558264.0
# Comedy       886752933.0
# Adventure    874211619.0
# Animation    873839108.0
# Crime        790482117.0
# Biography    753585104.0
# Mystery      474203697.0
# Fantasy      445151978.0
# Family       435110554.0
# Horror       298791505.0
# Film-Noir    123353292.0
# Western       31800000.0
# Thriller      17550741.0
# Name: Gross, dtype: float64

# %%
rowno = movies.groupby("Genre")['Gross'].idxmax()

df = movies.loc[rowno, ["Genre","Director"]]

# %%
df.to_csv("test.csv",index=False)

# %%
print(df)
# Out:
#          Genre          Director
# 477     Action       J.J. Abrams
# 323  Adventure      Ericson Core
# 229  Animation       Adam Elliot
# 276  Biography       David Lynch
# 557     Comedy      Henry Koster
# 451      Crime  Jacques Tourneur
# 913      Drama     Dennis Gansel
# 688     Family  Steven Spielberg
# 568    Fantasy       F.W. Murnau
# 712  Film-Noir  Alfred Hitchcock
# 876     Horror       James Whale
# 714    Mystery  Alfred Hitchcock
# 700   Thriller     Terence Young
# 691    Western    Clint Eastwood

# %%
display(df.style.hide(axis='index'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_35fc4" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_35fc4_level0_col0" class="col_heading level0 col0" >Genre</th>
#       <th id="T_35fc4_level0_col1" class="col_heading level0 col1" >Director</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35fc4_row0_col0" class="data row0 col0" >Action</td>
#       <td id="T_35fc4_row0_col1" class="data row0 col1" >J.J. Abrams</td>
#     </tr>
#     <tr>
#       <td id="T_35fc4_row1_col0" class="data row1 col0" >Adventure</td>
#       <td id="T_35fc4_row1_col1" class="data row1 col1" >Ericson Core</td>
#     </tr>
#     <tr>
#       <td id="T_35fc4_row2_col0" class="data row2 col0" >Animation</td>
#       <td id="T_35fc4_row2_col1" class="data row2 col1" >Adam Elliot</td>
#     </tr>
#     <tr>
#       <td id="T_35fc4_row3_col0" class="data row3 col0" >Biography</td>
#       <td id="T_35fc4_row3_col1" class="data row3 col1" >David Lynch</td>
#     </tr>
# ...

# %%
df.head()
# Out:
#          Genre      Director
# 477     Action   J.J. Abrams
# 323  Adventure  Ericson Core
# 229  Animation   Adam Elliot
# 276  Biography   David Lynch
# 557     Comedy  Henry Koster

# %%
movies.loc[movies.groupby("Genre")["IMDB_Rating"].idxmax(), ["Genre","Series_Title", "IMDB_Rating"]]
# Out:
#          Genre                     Series_Title  IMDB_Rating
# 2       Action                  The Dark Knight          9.0
# 21   Adventure                     Interstellar          8.6
# 23   Animation    Sen to Chihiro no kamikakushi          8.6
# 7    Biography                 Schindler's List          8.9
# 19      Comedy                     Gisaengchung          8.6
# 1        Crime                    The Godfather          9.2
# 0        Drama         The Shawshank Redemption          9.3
# 688     Family       E.T. the Extra-Terrestrial          7.8
# 321    Fantasy     Das Cabinet des Dr. Caligari          8.1
# 309  Film-Noir                    The Third Man          8.1
# 49      Horror                           Psycho          8.5
# 69     Mystery                          Memento          8.4
# 700   Thriller                  Wait Until Dark          7.8
# 12     Western  Il buono, il brutto, il cattivo          8.8

# %%
movies.groupby("Genre").nth(3)
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 6                                         Pulp Fiction          1994      154
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 17                     One Flew Over the Cuckoo's Nest          1975      133
# 35                                    The Intouchables          2011      112
# 52                                         City Lights          1931       87
# 56                                      Kimi no na wa.          2016      106
# 110                                           Das Boot          1981      149
# 145                                     Shutter Island          2010      138
# 419                                       The Exorcist          1973      122
# 691                             The Outlaw Josey Wales          1976      135
#
#          Genre  IMDB_Rating           Director              Star1  \
# ...

# %%
movies.groupby("Genre").min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
movies.groupby("Genre").agg({

       "Released_Year"    : "max",
       "Runtime" : "min"  ,
       "IMDB_Rating"     : "max"

}


)
# Out:
#           Released_Year  Runtime  IMDB_Rating
# Genre
# Action             2019       45          9.0
# Adventure            PG       88          8.6
# Animation          2020       71          8.6
# Biography          2020       93          8.9
# Comedy             2020       68          8.6
# Crime              2019       80          9.2
# Drama              2020       64          9.3
# Family             1982      100          7.8
# Fantasy            1922       76          8.1
# Film-Noir          1949      100          8.1
# Horror             2017       71          8.5
# Mystery            2012       96          8.4
# Thriller           1967      108          7.8
# Western            1976      132          8.8

# %%
movies.groupby("Genre").agg({"IMDB_Rating":["max","min"]})
# Out:
#           IMDB_Rating
#                   max  min
# Genre
# Action            9.0  7.6
# Adventure         8.6  7.6
# Animation         8.6  7.6
# Biography         8.9  7.6
# Comedy            8.6  7.6
# Crime             9.2  7.6
# Drama             9.3  7.6
# Family            7.8  7.8
# Fantasy           8.1  7.9
# Film-Noir         8.1  7.8
# Horror            8.5  7.6
# Mystery           8.4  7.6
# Thriller          7.8  7.8
# Western           8.8  7.8

# %%
movies.groupby("Genre").agg(["max","min"])
# Out:
#                                   Series_Title  \
#                                            max
# Genre
# Action                                 Yôjinbô
# Adventure                           Zombieland
# Animation          Ôkami kodomo no Ame to Yuki
# Biography                              Zerkalo
# Comedy                Zindagi Na Milegi Dobara
# Crime                        À bout de souffle
# Drama                                Zwartboek
# Family     Willy Wonka & the Chocolate Factory
# Fantasy                              Nosferatu
# Film-Noir                        The Third Man
# Horror                               The Thing
# Mystery                                Vertigo
# Thriller                       Wait Until Dark
# Western                 The Outlaw Josey Wales
#
#                                            Released_Year       Runtime       \
#                                        min           max   min     max  min
# Genre
# ...

# %%
movies.groupby("Genre").agg({

       "Released_Year"    : ["idxmax", "idxmin"],
       "Runtime" : "min"  ,
       "IMDB_Rating"     : "max" ,
       "Series_Title" : "max"

}


)
# Out:
#           Released_Year        Runtime IMDB_Rating  \
#                  idxmax idxmin     min         max
# Genre
# Action               59    194      45         9.0
# Adventure           966    193      88         8.6
# Animation           205    875      71         8.6
# Biography            18    317      93         8.9
# Comedy              464    127      68         8.6
# Crime                33    125      80         9.2
# Drama                20    462      64         9.3
# Family              688    698     100         7.8
# Fantasy             568    321      76         8.1
# Film-Noir           309    456     100         8.1
# Horror              724    876      71         8.5
# Mystery             220    714      96         8.4
# Thriller            700    700     108         7.8
# Western             691    115     132         8.8
#
#                                   Series_Title
#                                            max
# Genre
# ...
