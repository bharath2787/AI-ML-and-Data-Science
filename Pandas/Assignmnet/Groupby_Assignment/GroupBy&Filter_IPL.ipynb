# %% [markdown]
# # Pandas GroupBy Method Explained Using IPL Matches Dataset
#
# ## Introduction
#  - This notebook will demonstrate the use of the `groupby` method in pandas using the IPL (Indian Premier League) matches dataset. The `groupby` method is a powerful tool for aggregating data and performing various operations on grouped data.

# %%
## Importing Libraries

import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# #Loading the Dataset
#  - For this notebook, we will use a sample IPL matches dataset. You can download the dataset from Kaggle or any other source that provides IPL match data.

# %%
# Load the IPL matches dataset

df = pd.read_csv("/content/drive/MyDrive/a/IPLMatches.csv")


# Display the first few rows of the dataset
df.head()

# %%
df.columns

# %% [markdown]
# #Understanding the Dataset
# - Let's get a basic understanding of the dataset by checking its columns and some basic statistic

# %%
# Display basic information about the dataset
df.info()

# Display basic statistics of the dataset
df.describe()

# %% [markdown]
# #GroupBy Basics
#  - The groupby method is used to split the data into groups based on some criteria. Once the data is split, we can apply various aggregation functions on the groups.
#
# ##Question 1.1: Matches per Season
#  - hint: group the dataset by the season column and count the total number of matches played in each season.

# %% [markdown]
# ##Question 1.2: Matches per City
#  - Hint: Group the dataset by the city column to find out how many matches were played in each city.

# %% [markdown]
# ##Question 1.3: Wins per Team
#  - Hint: Group the dataset by the winner column to see how many matches each team has won.

# %% [markdown]
# #Example 2: Grouping by Multiple Columns
#  - We can also group by multiple columns. Let's group the dataset by season and city to find out how many matches were played in each city for each season.
#
# ##Question 2.1: Matches per Season and City
#  - Hint: Group the dataset by season and city to find out how many matches were played in each city for each season.

# %% [markdown]
# ##Question 2.2: Wins per Season and Team
#  - Hint: Group the dataset by season and winner to see how many matches each team has won in each season.

# %% [markdown]
# ##Question: 3 For every season find the final winners

# %% [markdown]
# ##Question:4 Find all the matches that have had super overs

# %% [markdown]
# ##Question:5 How many times did Punjab Kings win in Delhi

# %% [markdown]
# ##Question:6 Does winning a toss matter?

# %% [markdown]
# ##Question:7 Does Batting first matter?

# %% [markdown]
# ##Question8: Find the team that won by hightest wickets

# %% [markdown]
# ##Question:9 Find the team that won by max runs
