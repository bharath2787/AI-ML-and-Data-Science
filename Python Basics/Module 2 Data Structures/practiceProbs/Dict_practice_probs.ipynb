# %%
# Problem 1: `clear()` method
# Question: Create a dictionary with some sample key-value pairs and then use the `clear()` method to remove all elements from the dictionary.
# After clearing, print the dictionary.



# Problem 2: `copy()` method
# Question: Create a dictionary and use the `copy()` method to create a duplicate.
# Modify one element in the original dictionary and print both dictionaries to verify they are independent.


# Problem 3: `fromkeys()` method
# Question: Create a dictionary using the `fromkeys()` method with a list of keys and a default value of 0.
# Print the resulting dictionary.


# Problem 4: `get()` method
# Question: Use the `get()` method to access the value of a key in a dictionary.
# Handle the case where the key may not exist by using a default value.

# Problem 5: `items()` method
# Question: Iterate through the key-value pairs in a dictionary using the `items()` method and print each key-value pair.


# Problem 6: `keys()` method
# Question: Get and print all the keys of a dictionary using the `keys()` method.


# Problem 7: `pop()` method
# Question: Remove a specific key from a dictionary using the `pop()` method and print the dictionary after the removal.
# Handle the case when the key doesn't exist by using a default return value.


# Problem 8: `popitem()` method
# Question: Use the `popitem()` method to remove and return the last inserted key-value pair from a dictionary.


# Problem 9: `setdefault()` method
# Question: Use the `setdefault()` method to get the value of a key if it exists, or insert the key with a default value if it doesn't exist.
# Verify if the key was inserted when it was missing.


# Problem 10: `update()` method
# Question: Update a dictionary with another dictionary using the `update()` method.
# Print the dictionary before and after the update.

# Problem 11: `values()` method
# Question: Get all the values of a dictionary using the `values()` method and print them.


# Problem 12: Iterating through the dictionary keys and values
# Question: Use a loop to iterate through the dictionary and print both the key and value for each pair.
