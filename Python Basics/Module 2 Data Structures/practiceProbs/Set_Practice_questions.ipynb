# %% [markdown]
# # Python Set Operations - Practice Questions

# %% [markdown]
# ### **Question 1: Set Operations**
# Write a Python program that takes two sets of numbers and performs the following operations:
# - Find the **union** of both sets.
# - Find the **intersection** of both sets.
# - Find the **difference** (elements in the first set but not in the second).
#
# **Example Input:**
# ```python
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# ```
# **Expected Output:**
# ```
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}
# ```

# %%
# Write your code here
set1 = {1, 2, 3}
set2 = {3, 4, 5}
# Your code here

# %% [markdown]
# ### **Question 2: Remove Duplicates from a List**
# Write a function `remove_duplicates(lst)` that takes a list and returns a new list with duplicate values removed using a set.
#
# **Example Input:**
# ```python
# remove_duplicates([1, 2, 2, 3, 4, 4, 5])
# ```
# **Expected Output:**
# ```
# [1, 2, 3, 4, 5]
# ```

# %%
# Write your function here
def remove_duplicates(lst):
    pass

# Test the function
remove_duplicates([1, 2, 2, 3, 4, 4, 5])

# %% [markdown]
# ### **Question 3: Find Common Elements in Two Lists**
# Write a function that takes two lists and returns a set of common elements.
#
# **Example Input:**
# ```python
# list1 = [10, 20, 30, 40]
# list2 = [30, 40, 50, 60]
# ```
# **Expected Output:**
# ```
# Common elements: {30, 40}
# ```

# %%
# Write your function here
def find_common_elements(list1, list2):
    pass

# Test the function
list1 = [10, 20, 30, 40]
list2 = [30, 40, 50, 60]
find_common_elements(list1, list2)

# %% [markdown]
# ### **Question 4: Check if a Set is Empty**
# Write a function `is_empty(my_set)` that checks whether a given set is empty or not.
#
# **Example Input:**
# ```python
# is_empty(set())
# ```
# **Expected Output:**
# ```
# The set is empty
# ```

# %%
# Write your function here
def is_empty(my_set):
    pass

# Test the function
is_empty(set())

# %% [markdown]
# ### **Question 5: Count Unique Words in a Sentence**
# Write a function that takes a sentence as input and returns the number of unique words using a set. Ignore case differences.
#
# **Example Input:**
# ```python
# sentence = 'Python is fun and Python is powerful'
# ```
# **Expected Output:**
# ```
# Unique words count: 4
# ```

# %%
# Write your function here
def count_unique_words(sentence):
    pass

# Test the function
sentence = 'Python is fun and Python is powerful'
count_unique_words(sentence)
