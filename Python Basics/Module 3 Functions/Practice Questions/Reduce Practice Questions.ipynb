# %% [markdown]
# ---
#
# ### **1. Sum of All Elements**
# Use `reduce()` to find the sum of all numbers in a list.
#
# **Input:**
# ```python
# numbers = [1, 2, 3, 4, 5]
# ```
# **Expected Output:**
# ```python
# 15  # (1 + 2 + 3 + 4 + 5)
# ```
#
# ---
#
# ### **2. Product of All Elements**
# Use `reduce()` to calculate the product of all numbers in a list.
#
# **Input:**
# ```python
# numbers = [1, 2, 3, 4, 5]
# ```
# **Expected Output:**
# ```python
# 120  # (1 * 2 * 3 * 4 * 5)
# ```
#
# ---
#
# ### **3. Maximum Element in a List**
# Use `reduce()` to find the largest number in a list.
#
# **Input:**
# ```python
# numbers = [3, 10, 2, 8, 15, 6]
# ```
# **Expected Output:**
# ```python
# 15
# ```
#
# ---
#
# ### **4. Minimum Element in a List**
# Use `reduce()` to find the smallest number in a list.
#
# **Input:**
# ```python
# numbers = [3, 10, 2, 8, 15, 6]
# ```
# **Expected Output:**
# ```python
# 2
# ```
#
# ---
#
# ### **5. Concatenating Strings**
# Use `reduce()` to concatenate all strings in a list into a single string.
#
# **Input:**
# ```python
# words = ["Python", "is", "awesome"]
# ```
# **Expected Output:**
# ```python
# "Python is awesome"
# ```
#
# ---
#
# ### **6. Finding the Longest String**
# Use `reduce()` to find the longest string in a list of words.
#
# **Input:**
# ```python
# words = ["apple", "banana", "watermelon", "kiwi"]
# ```
# **Expected Output:**
# ```python
# "watermelon"
# ```
#
# ---
#
# ### **7. Creating a Dictionary from a List of Tuples**
# Use `reduce()` to convert a list of key-value tuples into a dictionary.
#
# **Input:**
# ```python
# pairs = [("a", 1), ("b", 2), ("c", 3)]
# ```
# **Expected Output:**
# ```python
# {"a": 1, "b": 2, "c": 3}
# ```
#
# ---
#
# ### **8. Finding the Second Largest Number**
# Use `reduce()` to find the **second largest** number in a list.
#
# **Input:**
# ```python
# numbers = [10, 25, 45, 67, 89, 100, 89]
# ```
# **Expected Output:**
# ```python
# 89  # The second largest number after 100
# ```
#
# ---
#
# ### **9. Finding the Most Frequent Element**
# Use `reduce()` to find the most frequently occurring element in a list.
#
# **Input:**
# ```python
# elements = ["apple", "banana", "apple", "cherry", "banana", "apple"]
# ```
# **Expected Output:**
# ```python
# "apple"
# ```
#
# ---
#
# ### **10. Finding the Difference Between Consecutive Elements**
# Use `reduce()` to calculate the difference between consecutive elements in a list.
#
# **Input:**
# ```python
# numbers = [100, 50, 25, 10, 5]
# ```
# **Expected Output:**
# ```python
# 10  # (((100 - 50) - 25) - 10) - 5
# ```
#
# ---
