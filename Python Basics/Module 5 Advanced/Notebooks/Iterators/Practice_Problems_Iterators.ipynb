# %% [markdown]
#  **10 basic-level iterator practice problems** in Python:
#
# ---
#
# ### **1. Create a Custom Iterator for Counting**
#    Implement a class `Counter` that behaves like an iterator, counting from `1` to `n`.
#    ```python
#    counter = Counter(5)
#    for num in counter:
#        print(num)  # Output: 1, 2, 3, 4, 5
#    ```
#
# ---
#
# ### **2. Create an Iterator for Even Numbers**
#    Define a class `EvenNumbers(n)` that iterates over even numbers up to `n`.
#
# ---
#
# ### **3. Implement an Infinite Iterator**
#    Create an iterator `InfiniteCounter(start)` that starts at `start` and increments indefinitely.
#
# ---
#
# ### **4. Implement a String Iterator**
#    Write a class `StringIterator` that iterates over characters in a string one at a time.
#    ```python
#    it = StringIterator("hello")
#    for char in it:
#        print(char)  # Output: 'h', 'e', 'l', 'l', 'o'
#    ```
#
# ---
#
# ### **5. Implement an Odd Number Iterator**
#    Define `OddIterator(n)`, which iterates over odd numbers up to `n`.
#
# ---
#
# ### **6. Create an Iterator for Squares of Numbers**
#    Write an iterator `SquareIterator(n)` that yields squares of numbers from `0` to `n-1`.
#
# ---
#
# ### **7. Implement a Reverse Iterator for a List**
#    Create `ReverseIterator(lst)`, which iterates over a list in reverse order.
#
# ---
#
# ### **8. Implement a Fibonacci Iterator**
#    Create a class `FibonacciIterator(n)`, which iterates over the first `n` Fibonacci numbers.
#
# ---
#
# ### **9. Create an Iterator for the Multiplication Table**
#    Write `MultiplicationTableIterator(num, n)`, which iterates over the first `n` multiples of `num`.
#
# ---
#
# ### **10. Implement a Range-like Iterator**
#    Create a custom iterator `CustomRange(start, stop, step)`, which behaves like Python’s built-in `range()`.
#
# ---
