# %% [markdown]
# # List Practice Questions (Basic & Advanced)
#
# This notebook contains both **basic** and **advanced** list practice questions to help you strengthen your list manipulation skills in Python.
#
# ---
#
# ##  **Basic List Questions**
#
# ### 1. **Basic List Operations**
# **Task:**
# Create a list of five numbers. Then, append a new number, remove an element, and print the updated list.
#
# ---
#
# ### 2. **List Indexing & Slicing**
# **Task:**
# Perform various **indexing** and **slicing** operations on the given list:
# - Access an element using its index.
# - Slice a sublist from the list.
# - Access the last element using negative indexing.
#
# ---
#
# ### 3. **List Comprehension**
# **Task:**
# Use list comprehension to generate a list of squares of numbers from **1 to 10**.
#
# ---
#
# ### 4. **Finding Maximum & Minimum Without Using `max()` and `min()`**
# **Task:**
# Find the **maximum** and **minimum** values in the list without using the built-in `max()` and `min()` functions.
#
# ---
#
# ### 5. **Merging and Sorting Lists**
# **Task:**
# - Merge two lists.
# - Sort the merged list in **ascending** order and print it.
#
# ---
#
# ##  **Advanced List Questions**
#
# ### 1. **Removing Duplicates Without Using `set()`**
# **Task:**
# Remove all **duplicates** from the given list without using the `set()` function, and return a list with unique elements.
#
# ---
#
# ### 2. **Find the Second Largest Number in a List (Without Using `max()`)**
# **Task:**
# Find the **second largest** number in the list without using the `max()` function.
#
# ---
#
# ### 3. **Rotate a List by `K` Positions**
# **Task:**
# Given a list and a value `K`, **rotate** the list to the right by `K` positions.
#
# ---
#
# ### 4. **Find All Pairs That Sum to a Target Value**
# **Task:**
# Find all **pairs** of numbers in the list whose sum is equal to the given target value.
#
# ---
#
# ### 5. **Count Occurrences of Each Element in a List**
# **Task:**
# Count how many times each element appears in the given list and return a dictionary with the elements as keys and their counts as values.
#
# ---
