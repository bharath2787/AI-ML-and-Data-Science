# %% [markdown]
# ---
#
# ### **1. Filtering Even Numbers**
# Write a Python program that filters out all even numbers from the given list using the `filter()` function.
#
# **Input:**
# ```python
# numbers = [10, 15, 20, 25, 30, 35, 40]
# ```
# **Expected Output:**
# ```python
# [10, 20, 30, 40]
# ```
#
# ---
#
# ### **2. Filtering Names with a Specific Letter**
# Given a list of names, use `filter()` to extract names that start with the letter **'A'**.
#
# **Input:**
# ```python
# names = ["Alice", "Bob", "Amanda", "Charlie", "Andrew"]
# ```
# **Expected Output:**
# ```python
# ["Alice", "Amanda", "Andrew"]
# ```
#
# ---
#
# ### **3. Filtering Non-Empty Strings**
# Write a program that removes all empty strings from the given list using `filter()`.
#
# **Input:**
# ```python
# words = ["hello", "", "world", "", "Python", " ", "filter"]
# ```
# **Expected Output:**
# ```python
# ["hello", "world", "Python", "filter"]
# ```
#
# ---
#
# ### **4. Filtering Prime Numbers**
# Create a function that filters out all prime numbers from a given list using `filter()`.
#
# **Input:**
# ```python
# numbers = [2, 3, 4, 5, 6, 7, 8, 9, 10]
# ```
# **Expected Output:**
# ```python
# [2, 3, 5, 7]
# ```
#
# ---
#
# ### **5. Filtering Words with Length Greater Than 5**
# Use `filter()` to extract words that have more than 5 characters.
#
# **Input:**
# ```python
# words = ["apple", "banana", "cherry", "kiwi", "watermelon", "grape"]
# ```
# **Expected Output:**
# ```python
# ["banana", "cherry", "watermelon"]
# ```
#
# ---
#
# ### **6. Filtering Divisible by 3**
# Filter out all numbers in the list that are **not** divisible by 3.
#
# **Input:**
# ```python
# numbers = [3, 6, 9, 12, 15, 20, 25, 30]
# ```
# **Expected Output:**
# ```python
# [3, 6, 9, 12, 15, 30]
# ```
#
# ---
#
# ### **7. Filtering Palindromes**
# Use `filter()` to keep only the palindrome words from a given list.
#
# **Input:**
# ```python
# words = ["madam", "racecar", "python", "level", "hello"]
# ```
# **Expected Output:**
# ```python
# ["madam", "racecar", "level"]
# ```
#
# ---
#
# ### **8. Filtering Employees by Age**
# Given a list of employees with their ages in a dictionary, filter out employees who are above 30 years old.
#
# **Input:**
# ```python
# employees = [("John", 28), ("Sarah", 35), ("Mike", 40), ("Anna", 24)]
# ```
# **Expected Output:**
# ```python
# [("Sarah", 35), ("Mike", 40)]
# ```
#
# ---
#
# ### **9. Filtering Vowels from a String**
# Use `filter()` to extract only vowels from a given string.
#
# **Input:**
# ```python
# text = "hello world"
# ```
# **Expected Output:**
# ```python
# ['e', 'o', 'o']
# ```
#
# ---
#
# ### **10. Filtering Numbers in a Range**
# Given a list of numbers, filter out only the numbers that are between 10 and 50.
#
# **Input:**
# ```python
# numbers = [5, 12, 30, 50, 75, 100, 18, 45]
# ```
# **Expected Output:**
# ```python
# [12, 30, 50, 18, 45]
# ```
#
# ---
