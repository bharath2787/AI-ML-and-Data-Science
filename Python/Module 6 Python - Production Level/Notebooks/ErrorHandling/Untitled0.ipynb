# %%
num = input("Enter a number: ")
print(int(num) + 5)
# Out:
# Enter a number: werwr
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-5c0a08699807> in <cell line: 0>()
#       1 num = input("Enter a number: ")
# ----> 2 print(int(num) + 5)
#
# ValueError: invalid literal for int() with base 10: 'werwr'

# %%
num = 10
print(num.append(5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-82d4abf6efe3> in <cell line: 0>()
#       1 num = 10
# ----> 2 print(num.append(5))
#
# AttributeError: 'int' object has no attribute 'append'

# %%
try:
    x = 10 / 0  # Division by zero
except ZeroDivisionError:
    print("You cannot divide by zero!")
# Out:
# You cannot divide by zero!

# %%
 x = 10 / 0  # Division by zero
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-b1c11f70b74a> in <cell line: 0>()
# ----> 1 x = 10 / 0  # Division by zero
#
# ZeroDivisionError: division by zero

# %%
try:
    num = int("hello")  # Invalid conversion
except ValueError:
    print("Invalid input! Cannot convert to integer.")
except TypeError:
    print("Type error occurred!")
# Out:
# Invalid input! Cannot convert to integer.

# %%
num = int("hello")  # Invalid conversion
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-bf47c0f7926b> in <cell line: 0>()
# ----> 1 num = int("hello")  # Invalid conversion
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
try:
    file = open("sample.txt", "r")
    print("file reading successful")
    content = file.read()
    # num = int("hello")  # Invalid conversion
except ValueError:
    print("Invalid input! Cannot convert to integer.")
except FileNotFoundError:
    print("File not found")
else:
  print("I am inside else loop")
finally:
  print("I am inside finally block")
# Out:
# file reading successful
# I am inside else loop
# I am inside finally block

# %%
"adfasdf" == 1234f
# Out:
#   File "<ipython-input-11-f3edf337c22e>", line 1
#     "adfasdf" == 1234f
#                     ^
# SyntaxError: invalid decimal literal

# %%
try:
    file = open("sample.txt", "r")
    content = file.read()
    num = int("hello")  # Invalid conversion
except Exception:
    print("Invalid input! Cannot convert to integer.")
# Out:
# Invalid input! Cannot convert to integer.

# %%
raise ValueError("this is my custom error message")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-348a2f63059e> in <cell line: 0>()
# ----> 1 raise ValueError("this is my custom error message")
#
# ValueError: this is my custom error message

# %%
age = 20

if age<21:
  raise ValueError("Age must be more than 30")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8e0452751c3b> in <cell line: 0>()
#       2
#       3 if age<21:
# ----> 4   raise ValueError("Age must be more than 30")
#
# ValueError: Age must be more than 30
