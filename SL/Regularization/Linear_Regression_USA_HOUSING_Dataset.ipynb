# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the dataset

# %%
# Ensure the file path is correct before running this cell


# Load the dataset
file_path = '/content/drive/MyDrive/0.Latest_DS_Course/SL/LinearRegression/Data/USA_Housing.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# # Inspect the dataset

# %%
# Display the first few rows of the dataset
display(df.head())

# Display basic information about the dataset
df.info()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Check for missing values in the dataset
print(df.isnull().sum())
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
# Dropping duplicates if any
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Univariate Analysis - Individual Column Analysis

# %%
# Analyzing 'Avg. Area Income'
plt.figure(figsize=(8, 4))
sns.histplot(df['Avg. Area Income'], bins=30, kde=True)
plt.title("Distribution of Avg. Area Income")
plt.show()
print("Observation: Most incomes are concentrated around a certain range, indicating a normal distribution.")
# Out:
# Observation: Most incomes are concentrated around a certain range, indicating a normal distribution.

# %% [markdown]
# - Most incomes cluster between **60,000 to 70,000**, indicating typical economic levels.
# - The distribution is **normal** and symmetric, reflecting balanced income spread.
# - Outliers below **40,000** or above **80,000** suggest regional economic extremes.
# - Insights can guide housing affordability and demand analysis.

# %%
# Analyzing 'Avg. Area House Age'
plt.figure(figsize=(8, 4))
sns.histplot(df['Avg. Area House Age'], bins=30, kde=True)
plt.title("Distribution of Avg. Area House Age")
plt.show()
print("Observation: The distribution appears fairly uniform, suggesting houses of various ages in the dataset.")
# Out:
# Observation: The distribution appears fairly uniform, suggesting houses of various ages in the dataset.

# %% [markdown]
# Here are insights from the histogram of average area house age:
#
# - **Typical House Age**: Most houses are around **6 years old**, as indicated by the peak in the histogram.
# - **Normal Distribution**: The house age follows a roughly **normal distribution**, with most counts centered around the mean.
# - **Age Extremes**: Very few houses are either **newer than 3 years** or **older than 9 years**, representing the tails of the distribution.
# - **Market Relevance**: The concentration of houses around 6 years suggests that the housing market in the area predominantly features relatively new properties, which may impact pricing and buyer preferences.

# %%
# Analyzing 'Avg. Area Number of Rooms'
plt.figure(figsize=(8, 4))
sns.histplot(df['Avg. Area Number of Rooms'], bins=30, kde=True)
plt.title("Distribution of Avg. Area Number of Rooms")
plt.show()
print("Observation: The number of rooms is somewhat normally distributed with a peak around the center.")
# Out:
# Observation: The number of rooms is somewhat normally distributed with a peak around the center.

# %% [markdown]
# - Most areas have an average of **7 rooms**, reflecting mid-sized housing trends.
# - The distribution is **normal**, showing consistency in housing configurations.
# - Outliers below **5 rooms** or above **9 rooms** suggest less common layouts.
# - Indicates market demand for balanced housing structures.

# %%
# Analyzing 'Avg. Area Number of Bedrooms'
plt.figure(figsize=(8, 4))
sns.histplot(df['Avg. Area Number of Bedrooms'], bins=30, kde=True)
plt.title("Distribution of Avg. Area Number of Bedrooms")
plt.show()
print("Observation: The number of bedrooms is slightly skewed, indicating that most houses have a similar number of bedrooms.")
# Out:
# Observation: The number of bedrooms is slightly skewed, indicating that most houses have a similar number of bedrooms.

# %% [markdown]
# - Most common: **3–4 bedrooms**, typical housing design.
# - Peaks at **2, 6 bedrooms** show smaller segments.
# - Rare: **5-bedroom houses**, less frequent.
# - Highlights housing preferences clearly.

# %%
# Analyzing 'Area Population'
plt.figure(figsize=(8, 4))
sns.histplot(df['Area Population'], bins=30, kde=True)
plt.title("Distribution of Area Population")
plt.show()
print("Observation: The population distribution varies significantly, showing high density in some areas.")
# Out:
# Observation: The population distribution varies significantly, showing high density in some areas.

# %% [markdown]
# - Most areas have populations between **30,000 and 40,000**, typical size.
# - Rare: Below **10,000** or above **60,000**, uncommon extremes.
# - Indicates moderate population influencing housing needs.

# %% [markdown]
# # Bivariate Analysis - Relationship between Each Feature and 'Price'

# %%
# Price vs Avg. Area Income
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['Avg. Area Income'], y=df['Price'])
plt.title("Price vs Avg. Area Income")
plt.show()
print("Observation: Higher income areas tend to have higher-priced houses.")
# Out:
# Observation: Higher income areas tend to have higher-priced houses.

# %% [markdown]
#  scatter plot of **Price vs Avg. Area Income**:
#
# - **Positive Correlation**: Higher average area incomes are associated with higher property prices.
# - **Income Influence**: Regions with incomes above **80,000** tend to have premium-priced homes.
# - **Economic Gradient**: Lower income areas (<40,000) show significantly reduced property values.
# - **Market Trend**: Income is a key driver of housing affordability and demand.

# %%
# Price vs Avg. Area House Age
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['Avg. Area House Age'], y=df['Price'])
plt.title("Price vs Avg. Area House Age")
plt.show()
print("Observation: House age does not show a strong correlation with price.")
# Out:
# Observation: House age does not show a strong correlation with price.

# %% [markdown]
# ### Insights from the Graph: "Price vs. Avg. Area House Age"
#
# 1. **Positive Correlation**: The scatter plot shows a weak to moderate positive correlation between the average house age and price, indicating that slightly older houses tend to have higher prices. However, the trend is not very strong.
#
# 2. **Wide Price Range**: At each house age level, there is a significant variation in house prices, suggesting that factors beyond just the age of the house influence pricing.
#
# 3. **Higher Density in Middle Ranges**: The majority of the data points are clustered between house ages of 5 to 8 years, indicating that most properties in the dataset fall within this age range.
#
# 4. **Outliers**: Some properties show extremely high or low prices compared to the general trend, suggesting that additional variables such as location, amenities, or demand may be influencing the pricing.
#
# ### Conclusion
# While there is a slight upward trend in prices as houses age, house age alone is not a strong predictor of price. Other factors like location, income levels, and house features likely play a bigger role in determining property values.

# %%
# Price vs Avg. Area Number of Rooms
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['Avg. Area Number of Rooms'], y=df['Price'])
plt.title("Price vs Avg. Area Number of Rooms")
plt.show()
print("Observation: More rooms generally lead to higher prices, but some variance exists.")
# Out:
# Observation: More rooms generally lead to higher prices, but some variance exists.

# %% [markdown]
# insights based on the scatter plot of **Price vs Avg. Area Number of Rooms**:
#
# - **Positive Correlation**: Houses with more rooms tend to have higher prices.
# - **Key Range**: Properties with **6 to 9 rooms** dominate the middle price tier.
# - **Luxury Indicator**: Homes with more than **10 rooms** often reach premium pricing.
# - **Market Implication**: Room count is a strong driver of property value.

# %%
# Price vs Avg. Area Number of Bedrooms
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['Avg. Area Number of Bedrooms'], y=df['Price'])
plt.title("Price vs Avg. Area Number of Bedrooms")
plt.show()
print("Observation: The number of bedrooms has a weaker correlation with price compared to other factors.")
# Out:
# Observation: The number of bedrooms has a weaker correlation with price compared to other factors.

# %% [markdown]
# insights for the scatter plot of **Price vs Avg. Area Number of Bedrooms**:
#
# - **Weak Correlation**: Property prices do not show a strong dependence on the average number of bedrooms.
# - **Similar Pricing**: Homes with **2 to 6 bedrooms** exhibit overlapping price ranges, indicating minimal price differentiation.
# - **Outlier Trend**: High-priced properties are scattered across all bedroom categories, suggesting other factors drive pricing.
# - **Market Insight**: The number of bedrooms alone is not a key determinant of property value.

# %%
# Price vs Area Population
plt.figure(figsize=(8, 4))
sns.scatterplot(x=df['Area Population'], y=df['Price'])
plt.title("Price vs Area Population")
plt.show()
print("Observation: Higher populated areas tend to have a wide range of housing prices.")
# Out:
# Observation: Higher populated areas tend to have a wide range of housing prices.

# %% [markdown]
#  insights for the scatter plot of **Price vs Area Population**:
#
# - **Weak Correlation**: Property prices do not strongly depend on the area's population size.
# - **Broad Spread**: Prices are dispersed across all population ranges, showing no clear trend.
# - **Outlier Trend**: High-priced properties occur even in sparsely populated areas, indicating other factors drive value.
# - **Market Insight**: Area population alone is not a strong predictor of property prices.

# %%
# Multivariate Analysis - Pairplot to check relationships between features
sns.pairplot(df)
plt.show()
print("Observation: The pairplot shows a strong linear relationship between Avg. Area Income and Price, and a moderate relationship between other variables.")
# Out:
# Observation: The pairplot shows a strong linear relationship between Avg. Area Income and Price, and a moderate relationship between other variables.

# %%
# Heatmap to visualize correlation between features
plt.figure(figsize=(6, 6))
sns.heatmap(df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
print("Observation: The heatmap reveals that 'Avg. Area Income' has the highest positive correlation with 'Price', while 'Avg. Area Number of Bedrooms' has the weakest correlation with 'Price'.")
# Out:
# Observation: The heatmap reveals that 'Avg. Area Income' has the highest positive correlation with 'Price', while 'Avg. Area Number of Bedrooms' has the weakest correlation with 'Price'.

# %% [markdown]
#  insights for the correlation matrix:
#
# - **Price Drivers**: Strong positive correlation with **Avg. Area Income (0.64)** and moderate correlation with **House Age (0.45)**, highlighting key influences.
# - **Room Impact**: Moderate correlation with **Number of Rooms (0.34)**; bedrooms show weak relevance (0.17).
# - **Population Factor**: **Moderate correlation (0.41)** indicates population plays a partial role in price trends.
# - **Design Relationship**: High correlation between **Rooms and Bedrooms (0.46)** suggests shared housing design patterns.

# %% [markdown]
# #Final Conclusion

# %% [markdown]
# After conducting an Exploratory Data Analysis (EDA) on the USA Housing dataset, several key insights have been identified:
#
# 1. **Income and Housing Prices**: There is a strong positive correlation between the average income in an area and the housing prices. Higher average incomes are associated with higher property values.
#
# 2. **House Age and Prices**: The age of houses does not exhibit a significant correlation with their prices. This suggests that newer homes do not necessarily command higher prices compared to older ones.
#
# 3. **Number of Rooms and Prices**: An increase in the average number of rooms in houses is moderately associated with higher housing prices. However, this relationship is not as pronounced as that between income and prices.
#
# 4. **Bedrooms and Prices**: The average number of bedrooms shows a weaker correlation with housing prices. This indicates that, beyond a certain point, additional bedrooms may not significantly influence property values.
#
# 5. **Population Density and Prices**: Areas with higher population densities exhibit a wide range of housing prices, suggesting that population density alone is not a strong determinant of housing costs.
#
# These insights underscore the importance of economic factors, particularly average income, in influencing housing prices. While structural attributes like the number of rooms have some impact, they are secondary to economic considerations. Understanding these relationships can aid stakeholders in making informed decisions in the real estate market.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Prepare the data by selecting relevant features
X = df.drop(columns=['Price', 'Address'])
y = df['Price']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Build the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on the training and test sets
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
model.score(X_train,y_train), model.score(X_test,y_test)
# Out:
# (0.9192986579075526, 0.914681849875402)

# %%
# Calculate performance metrics for both training and test sets
def adjusted_r2(r2, n, k):
    """Calculate the adjusted R²."""
    return 1 - (1 - r2) * (n - 1) / (n - k - 1)

# %%
# Training performance
mae_train = mean_absolute_error(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
rmse_train = mse_train ** 0.5
r2_train = r2_score(y_train, y_train_pred)
adj_r2_train = adjusted_r2(r2_train, len(y_train), X_train.shape[1])

# %%
# Test performance
mae_test = mean_absolute_error(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
rmse_test = mse_test ** 0.5
r2_test = r2_score(y_test, y_test_pred)
adj_r2_test = adjusted_r2(r2_test, len(y_test), X_test.shape[1])

# %%
print(f"\nTraining Performance:")
print(f"Mean Absolute Error (MAE): ${mae_train:.2f}")
print(f"Root Mean Squared Error (RMSE): ${rmse_train:.2f}")
print(f"R-squared (R²): {r2_train:.2f}")
print(f"Adjusted R-squared (Adj. R²): {adj_r2_train:.2f}")

print(f"\nTest Performance:")
print(f"Mean Absolute Error (MAE): ${mae_test:.2f}")
print(f"Root Mean Squared Error (RMSE): ${rmse_test:.2f}")
print(f"R-squared (R²): {r2_test:.2f}")
print(f"Adjusted R-squared (Adj. R²): {adj_r2_test:.2f}")
# Out:
# Training Performance:
# Mean Absolute Error (MAE): $81480.50
# Root Mean Squared Error (RMSE): $101425.06
# R-squared (R²): 0.92
# Adjusted R-squared (Adj. R²): 0.92
#
# Test Performance:
# Mean Absolute Error (MAE): $81135.57
# Root Mean Squared Error (RMSE): $100341.53
# R-squared (R²): 0.91
# Adjusted R-squared (Adj. R²): 0.91

# %%
# Compare training and test performance
print("\nPerformance Comparison:")
print(f"Training vs Test MAE: ${mae_train:.2f} vs ${mae_test:.2f}")
print(f"Training vs Test RMSE: ${rmse_train:.2f} vs ${rmse_test:.2f}")
print(f"Training vs Test R²: {r2_train:.2f} vs {r2_test:.2f}")
print(f"Training vs Test Adj. R²: {adj_r2_train:.2f} vs {adj_r2_test:.2f}")
# Out:
# Performance Comparison:
# Training vs Test MAE: $81480.50 vs $81135.57
# Training vs Test RMSE: $101425.06 vs $100341.53
# Training vs Test R²: 0.92 vs 0.91
# Training vs Test Adj. R²: 0.92 vs 0.91

# %% [markdown]
# ### Observations:
# - 1. The R² value of 0.91 indicates that the model explains 91% of the variance in house prices, which suggests a good fit.
# - 2. The RMSE of approximately $100,341.53 suggests that the model's predictions have an average error of this amount.
# - 3. The heatmap shows strong correlations between the target variable (Price) and features like Avg. Area Income and Avg. Area Number of Rooms.
# - 4. No missing values were detected in the dataset, which means the data is complete and ready for modeling.
# - 5. Further model improvement could be considered by exploring polynomial regression, feature engineering, or regularization techniques.

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# %%
# Train a Linear Regression model
lr = LinearRegression()
lr.fit(X_train, y_train)
y_pred_lr = lr.predict(X_test)

# Train Ridge Regression (L2 regularization)
ridge = Ridge(alpha=10)  # Adjust alpha for stronger regularization
ridge.fit(X_train, y_train)
y_pred_ridge = ridge.predict(X_test)

# Train Lasso Regression (L1 regularization)
lasso = Lasso(alpha=50000)  # Adjust alpha to make coefficients zero
lasso.fit(X_train, y_train)
y_pred_lasso = lasso.predict(X_test)

# Evaluate Performance
print("Linear Regression R²:", r2_score(y_test, y_pred_lr))
print("Ridge Regression R²:", r2_score(y_test, y_pred_ridge))
print("Lasso Regression R²:", r2_score(y_test, y_pred_lasso))
# Out:
# Linear Regression R²: 0.914681849875402
# Ridge Regression R²: 0.9146612348202572
# Lasso Regression R²: 0.8706279128552533
