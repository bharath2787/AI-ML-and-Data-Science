# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sal = [10,20,30,45,50]  #Range = 40k
sal1 = [10,20,30,45,50,10000] #  = 10000k =

# %%
10000/6
# Out:
# 1666.6666666666667

# %%
40/5
# Out:
# 8.0

# %%
df = pd.DataFrame(data=sal, columns=["Salary"])
df1 = pd.DataFrame(data=sal1, columns=["Salary"])

# %%
df
# Out:
#    Salary
# 0      10
# 1      20
# 2      30
# 3      45
# 4      50

# %%
df1
# Out:
#    Salary
# 0      10
# 1      20
# 2      30
# 3      45
# 4      50
# 5   10000

# %%
sns.boxplot(data=df, x="Salary")
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.boxplot(data=df1, x="Salary")
plt.xlim(0,60)
# Out:
# (0.0, 60.0)
