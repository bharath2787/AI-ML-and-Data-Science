# %%
print("this is some value")
# Out:
# this is some value

# %%
string = "this is the value of the string"

# %%
print("here is the string :"+string)
# Out:
# here is the string :this is the value of the string

# %%
print(f"here is the string : {string}")
# Out:
# here is the string : this is the value of the string

# %%
radius =4.5676543

# %%
print(f"this is the radius of the circle : {radius: .2f}")
# Out:
# this is the radius of the circle :  4.57

# %%
import numpy as np

# %%
a = np.array([1,2,3,4,5])

# %%
mean = a.mean()

# %%
a-1
# Out:
# array([0, 1, 2, 3, 4])

# %%
a- mean
# Out:
# array([-2., -1.,  0.,  1.,  2.])
