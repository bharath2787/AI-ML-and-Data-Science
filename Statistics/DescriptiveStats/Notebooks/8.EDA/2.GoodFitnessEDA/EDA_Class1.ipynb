# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/0.Latest_DS_Course/Statistics/Descriptive/8.EDA/data/CardioGoodFitness.csv")

# %% [markdown]
# #Understanding the Data

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# #Data Cleaning

# %%
# check for missing values

# %%
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
# observation: There are no missing values in the dataset

# %%
# checking for duplicate rows in dataset

df.duplicated().sum()
# Out:
# 0

# %%
#Observation: there are no duplicate rows in the dataset

# %%
#Data is already clean there are no missing values and no duplicate rows in the data

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# #Univariate Analysis

# %%
df.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %%
# product

# %%
sns.countplot(data=df, x="Product")
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
df['Product'].value_counts(normalize=True) *100
# Out:
# Product
# TM195    44.444444
# TM498    33.333333
# TM798    22.222222
# Name: proportion, dtype: float64

# %%
df.groupby("Product").size()
# Out:
# Product
# TM195    80
# TM498    60
# TM798    40
# dtype: int64

# %%
# Observations:
# - TM195 seems to be the most popular product , 45% customer bought this product
# second best selling product is TM498 , 33% customer bought this product
# 22% customers bought TM798

# %%
#Age
from scipy.stats import skew
sns.histplot(data=df, x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
skew(df['Age'])
# Out:
# 0.9739571319710887

# %%
df['Age'].describe()
# Out:
# count    180.000000
# mean      28.788889
# std        6.943498
# min       18.000000
# 25%       24.000000
# 50%       26.000000
# 75%       33.000000
# max       50.000000
# Name: Age, dtype: float64

# %%
#Observations:

# Age distribution is right skewed i.e most of the data point are on the left and there are few outlier on the right
# Avg age of the customers is 28.7, i.e most of the customers are young.
# most of the customers age is between 24 to 33 years.
# There are few outliers above 46 years.

# %%
#Gender


sns.countplot(data=df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      104
# Female     76
# Name: count, dtype: int64

# %%
df['Gender'].value_counts(normalize=True)*100
# Out:
# Gender
# Male      57.777778
# Female    42.222222
# Name: proportion, dtype: float64

# %%
df.groupby("Gender").size()
# Out:
# Gender
# Female     76
# Male      104
# dtype: int64

# %%
# # Observations

# - Most of the customers are Male around 58%
# - 42% of customers are female

# %%
#Education

sns.histplot(data=df, x="Education")
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Education")
# Out:
# <Axes: xlabel='Education'>

# %%
df['Education'].describe()
# Out:
# count    180.000000
# mean      15.572222
# std        1.617055
# min       12.000000
# 25%       14.000000
# 50%       16.000000
# 75%       16.000000
# max       21.000000
# Name: Education, dtype: float64

# %%
sns.countplot(data=df, x="Education")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
#MaritalStatus - categorica

# %%
sns.countplot(data=df, x="MaritalStatus")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
df['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# Name: count, dtype: int64

# %%
df['MaritalStatus'].value_counts(normalize=True)
# Out:
# MaritalStatus
# Partnered    0.594444
# Single       0.405556
# Name: proportion, dtype: float64

# %%
# Observations:

# - close to 60% customers belong to Male category and remaining 40% to female category

# %%
# Usage

# %%
sns.histplot(data=df, x="Usage")
# Out:
# <Axes: xlabel='Usage', ylabel='Count'>

# %%
sns.countplot(data=df, x="Usage")
# Out:
# <Axes: xlabel='Usage', ylabel='count'>

# %%
df['Usage'].value_counts()
# Out:
# Usage
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: count, dtype: int64

# %%
df['Usage'].value_counts(normalize=True)* 100
# Out:
# Usage
# 3    38.333333
# 4    28.888889
# 2    18.333333
# 5     9.444444
# 6     3.888889
# 7     1.111111
# Name: proportion, dtype: float64

# %%
# # Observations:

#  - 38% of user plan on using the product for 3 days a Week
#  - 28% 4 days a week
#  - 18 % 2 days a Week

# %%
df['Fitness'].value_counts(normalize=True)* 100
# Out:
# Fitness
# 3    53.888889
# 5    17.222222
# 2    14.444444
# 4    13.333333
# 1     1.111111
# Name: proportion, dtype: float64

# %%
# Income

# %%
sns.histplot(data=df, x="Income")
# Out:
# <Axes: xlabel='Income', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Income")
# Out:
# <Axes: xlabel='Income'>

# %%
df["Income"].describe()
# Out:
# count       180.000000
# mean      53719.577778
# std       16506.684226
# min       29562.000000
# 25%       44058.750000
# 50%       50596.500000
# 75%       58668.000000
# max      104581.000000
# Name: Income, dtype: float64

# %%
from scipy.stats import skew

# %%
skew(df['Income'])
# Out:
# 1.2809946733261928

# %%
# # Observations:

#  - mean income of customers is 53719.
#  - median income is 50596
#  - the Income distribution is right skewed which means there are outlier on the right above 80k.
#  - max income is 104581 and min income is 29562

# %%
#Miles

# %%
sns.histplot(data=df, x="Miles")
# Out:
# <Axes: xlabel='Miles', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Miles")
# Out:
# <Axes: xlabel='Miles'>

# %%
skew(df['Miles'])
# Out:
# 1.7100923922308489

# %%
df['Miles'].describe()
# Out:
# count    180.000000
# mean     103.194444
# std       51.863605
# min       21.000000
# 25%       66.000000
# 50%       94.000000
# 75%      114.750000
# max      360.000000
# Name: Miles, dtype: float64

# %%
# Observations
#  -  Miles distribution is a right skewed i.e. there are outlier above 180 on the right side
#  -  most of the customers plan on running 80 to 125 miles a week
#  -  Min miles is 21 and max is 360 miles.
#  -  Avg miles is 103

# %% [markdown]
# # BIVARIATE ANALYSYS

# %%
 # Product Vs Age

# %%
sns.histplot(data=df, x="Age", hue="Product")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(data=df, x="Age", hue="Product")
plt.legend(loc=0)

# %%
sns.violinplot(data=df, x="Age", hue="Product")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.displot(data=df, x="Age", col="Product")

# %%
# Observations:

# - TM798 : is being preferred by young ppl btween 25 to 33, there are outliers on the right i.e. ther are few old age ppl buying this product
# - TM195 : seems to be popular among a wide range of customers from Age perspective btween age group 18 to 45
#  -TM498 : seems to be popular among age 22 to 35

# %%
#Product Vs Gender

# %%
sns.countplot(data=df, x="Gender", hue="Product")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
cross_tab = pd.crosstab(df['Gender'], df['Product'])

# %%
df.shape
# Out:
# (180, 9)

# %%
cross_tab
# Out:
# Product  TM195  TM498  TM798
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
40/(40+29+7)
# Out:
# 0.5263157894736842

# %%
cross_tab.plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender')['Product'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Gender  Product
# Female  TM195      52.631579
#         TM498      38.157895
#         TM798       9.210526
# Male    TM195      38.461538
#         TM798      31.730769
#         TM498      29.807692
# Name: Percentage, dtype: float64

# %%
# Observations:
#  - TM798 : seems to be more popular among male than female , around 33 male customers bought this product compared to only 7 female customers

# %%
# Product Vs Education:

# %%
sns.histplot(data=df, x="Education", hue="Product")
# Out:
# <Axes: xlabel='Education', ylabel='Count'>

# %%
sns.displot(data=df, x="Education", col="Product")

# %%
cross_tab = pd.crosstab(df['Education'], df['Product'])

# %%
cross_tab.plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='Education'>

# %%
df.groupby('Education')['Product'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Education  Product
# 12         TM195       66.666667
#            TM498       33.333333
# 13         TM195       60.000000
#            TM498       40.000000
# 14         TM195       54.545455
#            TM498       41.818182
#            TM798        3.636364
# 15         TM195       80.000000
#            TM498       20.000000
# 16         TM195       45.882353
#            TM498       36.470588
#            TM798       17.647059
# 18         TM798       82.608696
#            TM195        8.695652
#            TM498        8.695652
# 20         TM798      100.000000
# 21         TM798      100.000000
# Name: Percentage, dtype: float64

# %%
# @Observations

# - Customers with higher education tend by TM798 more

# %%
cross_tab = pd.crosstab(df['MaritalStatus'], df['Product'])

# %%
cross_tab.plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='MaritalStatus'>

# %%
sns.countplot(data=df, x="MaritalStatus", hue="Product")
# Out:
# <Axes: xlabel='MaritalStatus', ylabel='count'>

# %%
# Observations
#  - partnered customer are buying more than single customers - across all the products

# %%
cross_tab = pd.crosstab(df['Usage'], df['Product'])

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Usage'>

# %%
# Observations:

# TM798 is being bought by the customers who plan to use 4+ days a Week
# TM195, 498  is bought by customers who are using it upto 4 days max
# Out:
#   File "<ipython-input-58-8a260b3276d9>", line 3
#     TM798 is being bought by the customers who plan to use 4+ days a Week
#                    ^
# SyntaxError: invalid syntax

# %%
cross_tab = pd.crosstab(df['Fitness'], df['Product'])

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Fitness'>

# %%
sns.countplot(data=df, x="Fitness", hue="Product")
# Out:
# <Axes: xlabel='Fitness', ylabel='count'>

# %%
sns.displot(data=df, x="Income", col="Product")

# %%
sns.boxplot(data=df, x="Income", hue="Product")
# Out:
# <Axes: xlabel='Income'>

# %%
# # Observations:

#  - customers earning 50k+ perfer TM798 , this could mean that ithis is a top variant in the product line
#  - customers with lowest earning tend to buy TM195 : 30k to 60k , this could be the base variant
#  - customers with salaries btween 40 to 60 prefer TM498 , this could be the mid variant

# %%
sns.displot(data=df, x="Miles", col="Product")

# %%
sns.boxplot(data=df, x="Miles", hue="Product")
# Out:
# <Axes: xlabel='Miles'>

# %%
# # Observations
#  - TM798 : ppl who plan to run 100+ miles per week prefer this product
#  - TM 498 : ppl who plan on running around 50 to 130 miles buy this prod
#  - TM195 : ppl who plan on running 50 to 120 miles per week go for this product
