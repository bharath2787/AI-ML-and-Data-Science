# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore') # To supress warnings
sns.set(style="whitegrid") # set the background for the graphs

# %%
titanic=pd.read_csv("/content/drive/MyDrive/0.Latest_DS_Course/Statistics/Descriptive/8.EDA/data/titanic.csv")
dftitanic=titanic.copy()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# # Obserservation

# Age column has 177 missing values
# Cabin column has 687 missing values
# Embarked column has 2 missing values

# %%
titanic.duplicated().sum()
# Out:
# 0

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic['Survived'].value_counts(normalize=True)
# Out:
# Survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
sns.countplot(data=titanic, x="Survived")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Univariate Analysis

# %%
#Pclass

sns.countplot(data=titanic, x="Pclass")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
titanic['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic.groupby('Pclass').size()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
# #observation
# 55% of the passanges were travelling in third class
# 24 % were in 1st class

# %%
# Sex

sns.countplot(data=titanic, x="Sex")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
titanic['Sex'].value_counts(normalize=True)*100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
# Observation
# majority of the passangers on the ship were male around 64%

# %%
sns.boxplot(data=titanic, x="Age")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.histplot(data=titanic, x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#Obeservation

# - average age of the pasengers on the ship is 28
# most of the ppl on the ship are around 20-40
# there are also some infants onboard around 40.
# ther are few passengers above 63 which makes the distribution right skewed

# %%
# SibSp


titanic['SibSp'].value_counts(normalize=True)
# Out:
# SibSp
# 0    0.682379
# 1    0.234568
# 2    0.031425
# 4    0.020202
# 3    0.017957
# 8    0.007856
# 5    0.005612
# Name: proportion, dtype: float64

# %%
sns.countplot(data=titanic, x="SibSp")
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
# most of the passagers on the ship around 68% are travelling alone
# there are 23 % ppl travelling with on sibling or spouse
# There are also very few passangers travelling with 4 - 8 siblings or spouses

# %%
#Parch


sns.countplot(data=titanic, x='Parch')
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
titanic['Parch'].value_counts(normalize=True) *100
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: proportion, dtype: float64

# %%
# # Observations

# around 76% passengers are travelling without any parent or children
# 13% with one parent or Child
# there are very few pasengers travelling with 2-6 parch

# %%
#Fare

# histplot, boxplot



sns.histplot(data=titanic, x="Fare")
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(data=titanic, x="Fare")
# Out:
# <Axes: xlabel='Fare'>

# %%
# # Observations
# there are passengers on the ship who havent paid any fare , could probably be the ship crew
# most of the passanges have paid less than 50$ fare
# there are also outliers like few ppl betwen 200-300 dollar and only one person who paid 500$ fare
# right skewed

# %%
titanic['Embarked'].value_counts(normalize=True)*100
# Out:
# Embarked
# S    72.440945
# C    18.897638
# Q     8.661417
# Name: proportion, dtype: float64

# %%
# # Observation

# most of the ppl boarded the ship at S boarding point - 72%
# very few ppl have boarded at Q boarding point

# %% [markdown]
# #Bivariate Analysis

# %%
#Pclass - categorical variable


sns.countplot(data = titanic , x = "Pclass", hue ="Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
titanic.groupby('Pclass')['Survived'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Pclass  Survived
# 1       1           62.962963
#         0           37.037037
# 2       0           52.717391
#         1           47.282609
# 3       0           75.763747
#         1           24.236253
# Name: Percentage, dtype: float64

# %%
cross_tab = pd.crosstab(titanic["Survived"], titanic["Pclass"])

# %%
cross_tab
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119

# %%
136/(80+136)
# Out:
# 0.6296296296296297

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.heatmap(cross_tab, annot=True, cmap="Blues", fmt="d")
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.histplot(data=titanic, x="Pclass", hue="Survived", multiple="stack")
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
#Observations

# Passegers who travelled in class 1 have highest chances of surviving , around 63% passengers survived
# class 3 passengers have least chances of surviving ,, only 24% passengers survived

# %%
#Survived VS Sex

titanic.groupby('Sex')['Survived'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Sex     Survived
# female  1           74.203822
#         0           25.796178
# male    0           81.109185
#         1           18.890815
# Name: Percentage, dtype: float64

# %%
cross_tab = pd.crosstab(titanic["Survived"], titanic["Sex"])

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Survived'>

# %%
# Observations

# Female passengers have 74% chances of surving while male have only 18 %

# %%
# Age VS Survived


sns.boxplot(data=titanic , x="Age", hue="Survived")
# Out:
# <Axes: xlabel='Age'>

# %%
sns.displot(data=titanic, x="Age", col="Survived", kde=True)

# %%
sns.histplot(data=titanic, x="Age", hue="Survived")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#observations

# age doesnt seem to play any role in Survival except for 0-5 years

# %%
# survived vs sibsp

sns.countplot(data = titanic, x= "SibSp", hue="Survived")
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
titanic.groupby('SibSp')['Survived'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# SibSp  Survived
# 0      0            65.460526
#        1            34.539474
# 1      1            53.588517
#        0            46.411483
# 2      0            53.571429
#        1            46.428571
# 3      0            75.000000
#        1            25.000000
# 4      0            83.333333
#        1            16.666667
# 5      0           100.000000
# 8      0           100.000000
# Name: Percentage, dtype: float64

# %%
# Observation

# %%
sns.countplot(data=titanic, x= "Parch", hue="Survived")
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
cross_tab = pd.crosstab(titanic["Survived"], titanic["Parch"])

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.heatmap(cross_tab, annot=True, cmap="Blues", fmt="d")
# Out:
# <Axes: xlabel='Parch', ylabel='Survived'>

# %%
titanic.groupby('Parch')['Survived'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Parch  Survived
# 0      0            65.634218
#        1            34.365782
# 1      1            55.084746
#        0            44.915254
# 2      0            50.000000
#        1            50.000000
# 3      1            60.000000
#        0            40.000000
# 4      0           100.000000
# 5      0            80.000000
#        1            20.000000
# 6      0           100.000000
# Name: Percentage, dtype: float64

# %%
# #Observation:

# ppl who were travelling with 1 PArch had the biggest chance of surviving 55%
# ppl who where travelling alone had 34% chances of surviving
# ppl who were travelling with 2 parch had 50 50 chances
# 4 and more had no chances of surviving

# %%
sns.histplot(data= titanic, x = "Fare", hue = "Survived")
plt.ylim(0,70)
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
# observation

# ppl who paid higher fair 100 dollar have higher chances of surviving

# %%
sns.countplot(data=titanic, x="Embarked", hue="Survived")
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
titanic.groupby('Embarked')['Survived'].value_counts(normalize = True).mul(100).rename('Percentage')
# Out:
# Embarked  Survived
# C         1           55.357143
#           0           44.642857
# Q         0           61.038961
#           1           38.961039
# S         0           66.304348
#           1           33.695652
# Name: Percentage, dtype: float64

# %%
cross_tab = pd.crosstab(titanic["Survived"], titanic["Embarked"])

# %%
cross_tab.plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.pairplot(data=titanic, hue="Survived")
