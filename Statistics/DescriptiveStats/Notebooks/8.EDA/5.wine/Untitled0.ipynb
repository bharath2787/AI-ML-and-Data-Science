# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from matplotlib import cm
warnings.filterwarnings('ignore')
pd.options.display.float_format = "{:.2f}".format

# %%
df = pd.read_csv("wine.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
#  13  color                 6497 non-null   object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            6497 non-null   int64
#  1   fixed acidity         6497 non-null   float64
#  2   volatile acidity      6497 non-null   float64
#  3   citric acid           6497 non-null   float64
#  4   residual sugar        6497 non-null   float64
#  5   chlorides             6497 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6497 non-null   float64
#  10  sulphates             6497 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
#  13  color                 6497 non-null   object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           0           7.00              0.27         0.36           20.70
# 1           1           6.30              0.30         0.34            1.60
# 2           2           8.10              0.28         0.40            6.90
# 3           3           7.20              0.23         0.32            8.50
# 4           4           7.20              0.23         0.32            8.50
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density   pH  \
# 0       0.04                45.00                170.00     1.00 3.00
# 1       0.05                14.00                132.00     0.99 3.30
# 2       0.05                30.00                 97.00     1.00 3.26
# 3       0.06                47.00                186.00     1.00 3.19
# 4       0.06                47.00                186.00     1.00 3.19
#
#    sulphates  alcohol  quality  color
# 0       0.45     8.80        6  white
# ...

# %%
df.shape
# Out:
# (6497, 14)

# %%
sns.countplot(data = df, x="color")
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
df["color"].value_counts(normalize=True)
# Out:
# color
# white   0.75
# red     0.25
# Name: proportion, dtype: float64

# %%
#observation :

# - 75% of the records belong to white class and only 25 % belong to red wine class which makes it an imbalanced dataset

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'color'],
#       dtype='object')

# %%
sns.histplot(data=df, x="fixed acidity")
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
sns.boxplot(data=df, x="fixed acidity")
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
df["fixed acidity"].describe()
# Out:
# count   6497.00
# mean       7.22
# std        1.30
# min        3.80
# 25%        6.40
# 50%        7.00
# 75%        7.70
# max       15.90
# Name: fixed acidity, dtype: float64

# %%
#Observation :
# - slightly right skewed
# there are outliers on both sides however more on the right side
# most of the wine samples have fixed acidity in the range 6.2 to 7.8

# %%
sns.histplot(data=df, x= "volatile acidity")
# Out:
# <Axes: xlabel='volatile acidity', ylabel='Count'>

# %%
sns.boxplot(data=df, x= "volatile acidity")
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
df["volatile acidity"].describe()
# Out:
# count   6497.00
# mean       0.34
# std        0.16
# min        0.08
# 25%        0.23
# 50%        0.29
# 75%        0.40
# max        1.58
# Name: volatile acidity, dtype: float64

# %%
# # Observations:

# - its a slightly right skewed distribution
# - most of the wines have volatile acidity in the range of .22 to .28

# %%
sns.histplot(data=df, x= "citric acid")
# Out:
# <Axes: xlabel='citric acid', ylabel='Count'>

# %%
df['citric acid'].describe()
# Out:
# count   6497.00
# mean       0.32
# std        0.15
# min        0.00
# 25%        0.25
# 50%        0.31
# 75%        0.39
# max        1.66
# Name: citric acid, dtype: float64

# %%
sns.boxplot(data=df, x="citric acid")
# Out:
# <Axes: xlabel='citric acid'>

# %%
# Observations:

# - There are a considerable number of wines having zero citric acid
# - Its a slightly right skewed sns.distributions
# - most of the wines have citric acid in the range "0.25 - 0.45"

# %%
sns.histplot(data=df, x="pH")
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
df['pH'].describe()
# Out:
# count   6497.00
# mean       3.22
# std        0.16
# min        2.72
# 25%        3.11
# 50%        3.21
# 75%        3.32
# max        4.01
# Name: pH, dtype: float64

# %%
sns.boxplot(data=df, x="pH")
# Out:
# <Axes: xlabel='pH'>

# %% [markdown]
# #bivariate

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'color'],
#       dtype='object')

# %%
sns.histplot(data=df, x= "fixed acidity", hue="quality" )
# Out:
# <Axes: xlabel='fixed acidity', ylabel='Count'>

# %%
sns.boxplot(data=df, x= "fixed acidity", hue="quality" )
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
sns.violinplot(data=df, x= "fixed acidity", hue="quality" )
# Out:
# <Axes: xlabel='fixed acidity'>

# %%
sns.displot(data=df, x= "fixed acidity", row="quality" )

# %%
sns.boxplot(data=df, x='volatile acidity', hue="quality")
# Out:
# <Axes: xlabel='volatile acidity'>

# %%
sns.displot(data=df, x="volatile acidity", col="quality")

# %%
# observation:

# volatile acidity is inversly proportional to the quality of the wine
# ppl like wines with less volatile acidity

# %%
sns.boxplot(data=df, x="citric acid", hue="quality")
# Out:
# <Axes: xlabel='citric acid'>

# %%
# observations:

# # ppl seem to like wines with high citric acid

# %%
def bivariate(colname):
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    # sns.histplot(df[col], kde=True)
    sns.boxplot(data=df, x=colname, hue="quality")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality', 'color'],
#       dtype='object')

# %%
cols = ['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
       ]

for each in cols:
  bivariate(each)

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.drop(columns=['color',"Unnamed: 0"]).corr(), annot=True, fmt='.2f', cmap='coolwarm')
# Out:
# <Axes: >

# %%
# 1: Highly correlated:
# # total sulphur die oxide and free sulfur dioxide seems to have a strong relation, drop one of them and try building model

# 2: weak relation
# # - density vs residual sugar have  .55 corr coeff , we can also try dropping one of these
