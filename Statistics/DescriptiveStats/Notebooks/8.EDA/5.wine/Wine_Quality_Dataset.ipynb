# %% [markdown]
# The Wine Quality dataset contains data on various physicochemical properties of red and white variants of Portuguese "Vinho Verde" wine. It is commonly used for classification and regression tasks in machine learning. The goal is typically to predict the quality of the wine based on its attributes.
#
# ### Dataset Details
#
# - **Source**: The dataset is available from the UCI Machine Learning Repository.
# - **Attributes**: It includes 11 input variables and 1 output variable.
#
# ### Attributes
#
# 1. **Fixed Acidity**: Most acids involved with wine or fixed or nonvolatile (do not evaporate readily).
# 2. **Volatile Acidity**: The amount of acetic acid in wine, which at too high of levels can lead to an unpleasant, vinegar taste.
# 3. **Citric Acid**: Found in small quantities, citric acid can add 'freshness' and flavor to wines.
# 4. **Residual Sugar**: The amount of sugar remaining after fermentation stops, important for determining the sweetness of the wine.
# 5. **Chlorides**: The amount of salt in the wine.
# 6. **Free Sulfur Dioxide**: The free form of SO2 exists in equilibrium between molecular SO2 (as a dissolved gas) and bisulfite ion; it prevents microbial growth and the oxidation of wine.
# 7. **Total Sulfur Dioxide**: Amount of free and bound forms of SO2; in low concentrations, SO2 is mostly undetectable in wine, but at free SO2 concentrations over 50 ppm, SO2 becomes evident in the nose and taste of wine.
# 8. **Density**: The density of water is close to that of water depending on the percent alcohol and sugar content.
# 9. **pH**: Describes how acidic or basic the wine is.
# 10. **Sulphates**: A wine additive which can contribute to sulfur dioxide gas (SO2) levels, acts as an antimicrobial and antioxidant.
# 11. **Alcohol**: The percent alcohol content of the wine.
#
# ### Output Variable
#
# - **Quality**: Wine quality score (between 0 and 10).
#
# ### Applications
#
# - **Classification**: Predicting the quality category of the wine (e.g., low, medium, high).
# - **Regression**: Predicting the exact quality score of the wine.
#
# ### Accessing the Dataset
#
# You can download the Wine Quality dataset from the UCI Machine Learning Repository:
# - [Wine Quality Dataset (UCI)](https://archive.ics.uci.edu/ml/datasets/wine+quality)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from matplotlib import cm
warnings.filterwarnings('ignore')
pd.options.display.float_format = "{:.2f}".format

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##LOAD DATASET

# %%
df_red =pd.read_csv("/content/drive/MyDrive/0.Latest_DS_Course/Statistics/Descriptive/8.EDA/data/winequality-red.csv",delimiter=";")

# %%
df_white =pd.read_csv("/content/drive/MyDrive/0.Latest_DS_Course/Statistics/Descriptive/8.EDA/data/winequality-white.csv",delimiter=";")

# %% [markdown]
# ##UNDERSTANDNG DATA

# %% [markdown]
# #### RED WINE DATASET

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                 34.00     1.00 3.51       0.56
# 1                25.00                 67.00     1.00 3.20       0.68
# 2                15.00                 54.00     1.00 3.26       0.65
# 3                17.00                 60.00     1.00 3.16       0.58
# 4                11.00                 34.00     1.00 3.51       0.56
#
#    alcohol  quality
# 0     9.40        5
# 1     9.80        5
# 2     9.80        5
# ...

# %%
df_red.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594           6.20              0.60         0.08            2.00       0.09
# 1595           5.90              0.55         0.10            2.20       0.06
# 1596           6.30              0.51         0.13            2.30       0.08
# 1597           5.90              0.65         0.12            2.00       0.07
# 1598           6.00              0.31         0.47            3.60       0.07
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 1594                32.00                 44.00     0.99 3.45       0.58
# 1595                39.00                 51.00     1.00 3.52       0.76
# 1596                29.00                 40.00     1.00 3.42       0.75
# 1597                32.00                 44.00     1.00 3.57       0.71
# 1598                18.00                 42.00     1.00 3.39       0.66
#
#       alcohol  quality
# 1594    10.50        5
# ...

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df_red.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_red.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# #### WHITE WINE DATASET

# %%
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.00              0.27         0.36           20.70       0.04
# 1           6.30              0.30         0.34            1.60       0.05
# 2           8.10              0.28         0.40            6.90       0.05
# 3           7.20              0.23         0.32            8.50       0.06
# 4           7.20              0.23         0.32            8.50       0.06
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                45.00                170.00     1.00 3.00       0.45
# 1                14.00                132.00     0.99 3.30       0.49
# 2                30.00                 97.00     1.00 3.26       0.44
# 3                47.00                186.00     1.00 3.19       0.40
# 4                47.00                186.00     1.00 3.19       0.40
#
#    alcohol  quality
# 0     8.80        6
# 1     9.50        6
# 2    10.10        6
# ...

# %%
df_white.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893           6.20              0.21         0.29            1.60       0.04
# 4894           6.60              0.32         0.36            8.00       0.05
# 4895           6.50              0.24         0.19            1.20       0.04
# 4896           5.50              0.29         0.30            1.10       0.02
# 4897           6.00              0.21         0.38            0.80       0.02
#
#       free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 4893                24.00                 92.00     0.99 3.27       0.50
# 4894                57.00                168.00     0.99 3.15       0.46
# 4895                30.00                111.00     0.99 2.99       0.46
# 4896                20.00                110.00     0.99 3.34       0.38
# 4897                22.00                 98.00     0.99 3.26       0.32
#
#       alcohol  quality
# 4893    11.20        6
# ...

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_white.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
df_white.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df_red.columns, df_white.columns
# Out:
# (Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#         'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#         'pH', 'sulphates', 'alcohol', 'quality'],
#        dtype='object'),
#  Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#         'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#         'pH', 'sulphates', 'alcohol', 'quality'],
#        dtype='object'))

# %%
df_red.to_csv("red.csv")

# %%
df_red.duplicated().sum()
# Out:
# 240

# %%
df_white.duplicated().sum()
# Out:
# 937

# %% [markdown]
# ### Observations
#
# - The red wine dataset contains 1,599 records and 13 attributes, while the white wine dataset contains 4,898 records with the same attributes.
# - Both datasets are clean, with no missing values or duplicate entries.
# - For more comprehensive analysis, we plan to merge the two datasets and add a new categorical column to indicate the wine color.
# - The data types across all columns are consistent and appropriate.

# %% [markdown]
# #### Merge both datasets, adding color column to distinguish between white and red wine records

# %%
df_red.shape, df_white.shape
# Out:
# ((1599, 12), (4898, 12))

# %%
# create color array for red dataframe
color_red = np.repeat('red', df_red.shape[0])

# create color array for white dataframe
color_white = np.repeat('white', df_white.shape[0])

# %%
color_red, len(color_red)
# Out:
# (array(['red', 'red', 'red', ..., 'red', 'red', 'red'], dtype='<U3'), 1599)

# %%
df_red.columns == df_white.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
df_red.shape, df_white.shape
# Out:
# ((1599, 12), (4898, 12))

# %%
# appending new column and confirming changes
df_white['color'] = color_white
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.00              0.27         0.36           20.70       0.04
# 1           6.30              0.30         0.34            1.60       0.05
# 2           8.10              0.28         0.40            6.90       0.05
# 3           7.20              0.23         0.32            8.50       0.06
# 4           7.20              0.23         0.32            8.50       0.06
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                45.00                170.00     1.00 3.00       0.45
# 1                14.00                132.00     0.99 3.30       0.49
# 2                30.00                 97.00     1.00 3.26       0.44
# 3                47.00                186.00     1.00 3.19       0.40
# 4                47.00                186.00     1.00 3.19       0.40
#
#    alcohol  quality  color
# 0     8.80        6  white
# 1     9.50        6  white
# ...

# %%
# appending new column and confirming changes
df_red['color'] = color_red
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.40              0.70         0.00            1.90       0.08
# 1           7.80              0.88         0.00            2.60       0.10
# 2           7.80              0.76         0.04            2.30       0.09
# 3          11.20              0.28         0.56            1.90       0.07
# 4           7.40              0.70         0.00            1.90       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                11.00                 34.00     1.00 3.51       0.56
# 1                25.00                 67.00     1.00 3.20       0.68
# 2                15.00                 54.00     1.00 3.26       0.65
# 3                17.00                 60.00     1.00 3.16       0.58
# 4                11.00                 34.00     1.00 3.51       0.56
#
#    alcohol  quality color
# 0     9.40        5   red
# 1     9.80        5   red
# ...

# %% [markdown]
# ###CONCATINATING BOTH DATASETS

# %%
# append dataframes and confirm changes
wine_df = pd.concat([df_white, df_red], axis = 0, ignore_index = True)
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0           7.00              0.27         0.36           20.70       0.04
# 1           6.30              0.30         0.34            1.60       0.05
# 2           8.10              0.28         0.40            6.90       0.05
# 3           7.20              0.23         0.32            8.50       0.06
# 4           7.20              0.23         0.32            8.50       0.06
#
#    free sulfur dioxide  total sulfur dioxide  density   pH  sulphates  \
# 0                45.00                170.00     1.00 3.00       0.45
# 1                14.00                132.00     0.99 3.30       0.49
# 2                30.00                 97.00     1.00 3.26       0.44
# 3                47.00                186.00     1.00 3.19       0.40
# 4                47.00                186.00     1.00 3.19       0.40
#
#    alcohol  quality  color
# 0     8.80        6  white
# 1     9.50        6  white
# ...

# %%
wine_df.to_csv("wine.csv")

# %%
wine_df.shape[0] == df_red.shape[0] +df_white.shape[0]
# Out:
# True

# %%
df_red.duplicated().sum(), df_white.duplicated().sum()
# Out:
# (240, 937)

# %%
df_red.duplicated().sum() + df_white.duplicated().sum()
# Out:
# 1177

# %%
wine_df.duplicated().sum() == df_red.duplicated().sum() + df_white.duplicated().sum()
# Out:
# True

# %%
wine_df.duplicated().sum()
# Out:
# 1177

# %%
wine_df = wine_df.drop_duplicates()

# %%
wine_df.duplicated().sum()
# Out:
# 0

# %%
wine_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
wine_df.shape
# Out:
# (5320, 13)

# %%
wine_df.to_csv("wine.csv")

# %%
# casting color column and confirming changes
wine_df['color'] = wine_df['color'].astype('category')
wine_df['color'].dtype
# Out:
# CategoricalDtype(categories=['red', 'white'], ordered=False, categories_dtype=object)

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5320 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         5320 non-null   float64
#  1   volatile acidity      5320 non-null   float64
#  2   citric acid           5320 non-null   float64
#  3   residual sugar        5320 non-null   float64
#  4   chlorides             5320 non-null   float64
#  5   free sulfur dioxide   5320 non-null   float64
#  6   total sulfur dioxide  5320 non-null   float64
#  7   density               5320 non-null   float64
#  8   pH                    5320 non-null   float64
#  9   sulphates             5320 non-null   float64
#  10  alcohol               5320 non-null   float64
#  11  quality               5320 non-null   int64
#  12  color                 5320 non-null   category
# dtypes: category(1), float64(11), int64(1)
# memory usage: 545.6 KB

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %% [markdown]
# ## DATA CLEANING

# %%
#Check for null values:
wine_df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# color                   0
# dtype: int64

# %%
#Check for duplicates
wine_df.duplicated().sum()
# Out:
# 0

# %%
#Data Type Correction

wine_df.dtypes
# Out:
# fixed acidity            float64
# volatile acidity         float64
# citric acid              float64
# residual sugar           float64
# chlorides                float64
# free sulfur dioxide      float64
# total sulfur dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                    int64
# color                   category
# dtype: object

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count        5320.00           5320.00      5320.00         5320.00
# mean            7.22              0.34         0.32            5.05
# std             1.32              0.17         0.15            4.50
# min             3.80              0.08         0.00            0.60
# 25%             6.40              0.23         0.24            1.80
# 50%             7.00              0.30         0.31            2.70
# 75%             7.70              0.41         0.40            7.50
# max            15.90              1.58         1.66           65.80
#
#        chlorides  free sulfur dioxide  total sulfur dioxide  density      pH  \
# count    5320.00              5320.00               5320.00  5320.00 5320.00
# mean        0.06                30.04                114.11     0.99    3.22
# std         0.04                17.81                 56.77     0.00    0.16
# ...

# %% [markdown]
# ##Check the class distribution

# %%
sns.countplot(data=wine_df, x='color')
# Out:
# <Axes: xlabel='color', ylabel='count'>

# %%
wine_df['color'].value_counts(normalize=True)
# Out:
# color
# white   0.74
# red     0.26
# Name: proportion, dtype: float64

# %%
# Custom color palette
custom_palette = ['#FF9999', '#66B3FF']  # Red and white wine colors

# Count plot
sns.countplot(data=wine_df, x='color', palette=custom_palette)
plt.title('Count of Wine Colors')
plt.xlabel('Wine Color')
plt.ylabel('Count')
plt.show()

# %%
wine_df.groupby('color')['color'].count()
# Out:
# color
# red      1359
# white    3961
# Name: color, dtype: int64

# %%
wine_df['color'].value_counts()
# Out:
# color
# white    3961
# red      1359
# Name: count, dtype: int64

# %%
wine_df['color'].value_counts(normalize=True)
# Out:
# color
# white   0.74
# red     0.26
# Name: proportion, dtype: float64

# %%
# Count occurrences of each color
color_counts = wine_df['color'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(color_counts, labels=color_counts.index, autopct='%1.1f%%', startangle=140, colors=['#FF9999', '#66B3FF'])
plt.title('Distribution of Wine Colors')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# ### Analysis of Class Distribution:
#
# - **White Wine**: There are significantly more white wine samples than red wine samples in the dataset. The count of white wine samples is close to 5,000, which makes up the majority of the dataset.
# - **Red Wine**: The count of red wine samples is around 1,500, which is considerably smaller compared to white wine.
#
# ### Implications:
# - **Imbalance**: The dataset is imbalanced, with white wine samples outnumbering red wine samples by more than three times. This imbalance could potentially impact the performance of machine learning models, particularly those sensitive to class distribution (e.g., classification algorithms).
# - **Analysis Considerations**: When analyzing or building models, it's important to account for this imbalance. Techniques such as stratified sampling, resampling (oversampling the minority class or undersampling the majority class), or using weighted models might be necessary to ensure that the model does not become biased toward the majority class (white wine).

# %%
df = wine_df
# Univariate analysis for numerical columns
for col in ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
            'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
            'pH', 'sulphates', 'alcohol']:
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], kde=True)
    plt.title(f'{col} - Histogram')

    plt.subplot(1, 2, 2)
    sns.boxplot(x=df[col])
    plt.title(f'{col} - Box Plot')

    plt.show()

# %% [markdown]
# ### Analysis of 'Fixed Acidity':
#
# 1. **Histogram Analysis**:
#    - The histogram shows that the distribution of 'fixed acidity' is slightly skewed to the right, meaning there are more values on the lower end (around 6-7) and fewer values on the higher end.
#    - The most common range for fixed acidity is between 6 and 8, with a peak around 7.
#    - The distribution tails off as the acidity increases, with very few wines having a fixed acidity above 10.
#
# 2. **Box Plot Analysis**:
#    - The box plot indicates that the median value of fixed acidity is slightly below 7.
#    - The interquartile range (IQR), representing the middle 50% of the data, lies approximately between 6 and 8.
#    - There are a significant number of outliers on the higher end, indicating that some wines have unusually high fixed acidity levels. These outliers extend beyond 10, with a few reaching up to 16.
#    - There are also a few lower-end outliers, although they are much fewer compared to the higher end.

# %%
# Univariate analysis for ordinal column 'quality'
sns.countplot(x='quality', data=df)
plt.title('Count Plot for Wine Quality')
plt.show()

# %% [markdown]
# ### Observations from the Count Plot:
# - **Quality Distribution**: The wine quality is rated from 3 to 9. The most common wine quality ratings are 5, 6, and 7, with 6 being the most frequent. This suggests that the majority of the wines in the dataset are of average quality.
# - **Skewness**: The distribution is slightly skewed towards lower quality (5 and 6), with fewer samples rated as very high quality (8 or 9) and very low quality (3 or 4).
#
# ### Next Steps in Analysis:
# 1. **Bivariate Analysis**: Investigate the relationship between wine quality and other features such as alcohol content, acidity, or residual sugar.
# 2. **Correlation Analysis**: Perform a correlation analysis to see which features are most correlated with wine quality.
# 3. **Outlier Detection**: Identify if there are any outliers in the data that could impact the analysis.
# 4. **Feature Importance**: If you plan on building a predictive model, evaluate the importance of various features in predicting wine quality.

# %%
# Now include the 'color_numeric' in the correlation calculation
corr = wine_df.drop(columns=['color']).corr()


# Plotting the correlation heatmap
plt.figure(figsize=(12, 6))
mask = np.triu(corr)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.title("Correlation between Attributes (including Color)")
plt.show()

# %% [markdown]
# ### Key Observations:
# 1. **Positive Correlations**:
#    - **Alcohol and Quality**: The correlation between alcohol and quality is \(0.47\), indicating a moderate positive relationship. Wines with higher alcohol content tend to have better quality ratings.
#    - **Total Sulfur Dioxide and Free Sulfur Dioxide**: This correlation is \(0.72\), indicating a strong positive relationship. This makes sense as total sulfur dioxide is likely to include free sulfur dioxide.
#    - **Density and Residual Sugar**: The correlation between density and residual sugar is \(0.52\), showing a moderate positive relationship. Higher residual sugar generally increases the density of the wine.
#
# 2. **Negative Correlations**:
#    - **Density and Alcohol**: The correlation between density and alcohol is \(-0.67\), indicating a strong negative relationship. This suggests that as alcohol content increases, the density of the wine decreases, which is expected since alcohol is less dense than water.
#    - **pH and Fixed Acidity**: The correlation here is \(-0.27\), showing a weak negative relationship. This suggests that wines with higher fixed acidity tend to have lower pH values (more acidic).
#
# 3. **Other Correlations**:
#    - **Volatile Acidity and Quality**: The correlation is \(-0.27\), which shows a weak negative correlation. Higher volatile acidity tends to slightly reduce the quality of the wine.
#    - **Sulphates and Quality**: There is a small positive correlation of \(0.04\) with wine quality, suggesting that sulphates have a minimal positive effect on the quality.
#
# ### Insights:
# - **Alcohol Content**: It plays a significant role in determining wine quality as it has the highest positive correlation with quality among all features.
# - **Sulfur Dioxide Levels**: The strong positive correlation between free and total sulfur dioxide indicates that these two measures are closely related and likely contribute to the preservation of wine.
# - **Density and Alcohol**: The strong negative correlation shows that alcohol content influences the density, which could be a critical factor in distinguishing different types of wines.
#
# ### Summary:
# The correlation matrix provides valuable insights into how different features of wine influence its quality. Alcohol content and sulfur dioxide levels are particularly important, while pH and volatile acidity also play roles in determining quality. However, the correlations alone cannot fully explain the quality; other factors and non-linear relationships may also be at play.

# %%
# Scatter plot for numerical vs numerical
sns.scatterplot(y='alcohol', x='quality', data=df)
plt.title('Alcohol vs Quality')
plt.show()

# %%
# Box plot for numerical vs categorical
sns.boxplot(x='quality', y='alcohol', data=df)
plt.title('alcohol vs Quality')
plt.show()

# %%
# Boxplot of wine Density
plt.figure(figsize=(15,15))
sns.boxplot(x = 'quality', y = 'pH', data = wine_df, palette='Reds')
plt.xlabel("Quality Rating", fontsize = 16)
plt.ylabel("PH", fontsize = 16)
plt.title("PH by Wine Quality", fontsize = 20)
plt.show()

# %%
# Boxplot of wine Density
plt.figure(figsize=(15,15))
sns.boxplot(x = 'quality', y = 'density', data = wine_df, palette='Reds')
plt.xlabel("Quality Rating", fontsize = 16)
plt.ylabel("density", fontsize = 16)
plt.title("Density by Wine Quality", fontsize = 20)
plt.show()

# %% [markdown]
# As we can observe from the above plot, density seems to be inversly related to quality

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
# Boxplot of wine Density
plt.figure(figsize=(15,15))
sns.boxplot(x = 'quality', y = 'citric acid', data = wine_df, palette='Reds')
plt.xlabel("Quality Rating", fontsize = 16)
plt.ylabel("citric", fontsize = 16)
plt.title("citric by Wine Quality", fontsize = 20)
plt.show()

# %% [markdown]
# Citric acid is added to give ‘freshness’ and flavor to wines. I’m not sure how it’s measured, but it looks as the more the merrier! High rated wines seem to have higher citric acid levels and tend to be in a tighter range than the lower rated wines (notice the length of the rectangles for lower rated wines).

# %%
# Violin Catplot of wine Fixed Acidity
plt.figure(figsize=(20,20))
sns.catplot(x = 'quality', y = 'fixed acidity', kind="violin", data = wine_df, palette='Reds')
plt.xlabel("Quality Rating", fontsize = 16)
plt.ylabel("Fixed Acidity", fontsize = 16)
plt.title("Fixed Acidity of Wine Quality", fontsize = 20)
plt.show()

# %% [markdown]
# For ‘fixed acidity’ it hard to state any obvious conclusions. Perhaps fixed acidity is dependent on numerous other features and is less of a signal as it is just a measurable feature. The wine with a higher quality rating seem to be spread out all over the map — meaning that good tasting wines can have a high or a low fixed acidity. Whereas the lower rated wines tend to be more clustered together around the median.

# %%
# # Correlation heatmap for numerical variables
# plt.figure(figsize=(12, 8))
# sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
# plt.title('Correlation Heatmap')
# plt.show()

# %%
# Box plot for numerical vs categorical
sns.boxplot(x='quality', y='fixed acidity', data=df)
plt.title('Fixed Acidity vs Quality')
plt.show()

# %%
# Violin plot for numerical vs categorical
sns.violinplot(x='color', y='residual sugar', data=df)
plt.title('Residual Sugar vs Wine Color')
plt.show()

# %%
# Cross-tabulation for categorical vs categorical
cross_tab = pd.crosstab(df['color'], df['quality'])
print(cross_tab)
# Out:
# quality   3    4     5     6    7    8  9
# color
# red      10   53   577   535  167   17  0
# white    20  153  1175  1788  689  131  5

# %%
# Stacked bar plot for categorical vs categorical
cross_tab.plot(kind='bar', stacked=True)
plt.title('Wine Color vs Quality')
plt.show()

# %%
figure = plt.figure(figsize = (10,5))
ax = sns.countplot(x = "quality", hue = "color", data = wine_df)
plt.title("wine quality distribution with color")
ax.bar_label(ax.containers[0], label_type='edge')
ax.bar_label(ax.containers[1], label_type='edge')
plt.show()

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
sns.displot(x='quality', hue = 'color', data = wine_df)

# %% [markdown]
# there is noticable deviation between white and red wine counts.
# most of the white wine has a quality of 6, while most of the red wine has a quality of 5.

# %%
figure = plt.figure(figsize = (10,5))
ax = sns.barplot(x = "color", y = "quality", data = wine_df)
plt.title("wine quality against color")
plt.show()

# %%
# viewing stats about alcoholic content
wine_df['alcohol'].describe()
# Out:
# count   5320.00
# mean      10.55
# std        1.19
# min        8.00
# 25%        9.50
# 50%       10.40
# 75%       11.40
# max       14.90
# Name: alcohol, dtype: float64

# %% [markdown]
# we have the highst alcohol content at 14.9.
# most of the wine has alcoholic content around 10.4.

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
wine_df.shape
# Out:
# (5320, 13)

# %%
# plotting alcohol and quality
figure = plt.figure(figsize = (10,5))
ax = sns.barplot(x = "quality", y = "residual sugar", data = wine_df, color = '#4287f5', ci = None)
ax.bar_label(ax.containers[0], label_type='edge')
plt.title("wine quality against residual sugar content")
plt.show()

# %% [markdown]
# we can see that the highest sugar content is tied to a quality of 5, while lower sugar content appears to have respectively higher quality.

# %%
def catigorize_col (df, col, labels):
    """
    catigorizes a certain column based on its quartiles

    Args:
        (df)     df   - dataframe we are proccesing
        (col)    str  - to be catigorized column's name
        (labels) list - list of labels from min to max

    Returns:
        (df)     df   - dataframe with the categorized col
    """

    # setting the edges to cut the column accordingly
    edges = [df[col].describe()['min'],
             df[col].describe()['25%'],
             df[col].describe()['50%'],
             df[col].describe()['75%'],
             df[col].describe()['max']]

    df[col] = pd.cut(df[col], edges, labels = labels, duplicates='drop')
    return df

# %%
# define pH labels
labels = ['High', 'Average', 'BelowAverage', 'Low']

# categorize values
catigorize_col(wine_df, 'pH', labels)

# confirm changes
wine_df['pH'].dtype
# Out:
# CategoricalDtype(categories=['High', 'Average', 'BelowAverage', 'Low'], ordered=True, categories_dtype=object)

# %%
wine_df[wine_df.pH=='Low'].shape
# Out:
# (1267, 13)

# %%
# plotting acidity dist
figure = plt.figure(figsize = (10,5))
ax = sns.countplot(x = "pH", data = wine_df, color = '#4287f5',
                   order = wine_df['pH'].value_counts().index,)
ax.bar_label(ax.containers[0], label_type='edge')
plt.title("acidity levels distribution")
plt.show()

# %%
# plotting quality against acidity levels in pH
figure = plt.figure(figsize = (10,5))
ax = sns.barplot(y = "quality", x = "pH", data = wine_df, color = '#4287f5')
plt.title("wine quality against acidity levels")
plt.show()

# %%
# Find the mean quality of each acidity level in pH with groupby
wine_df.groupby('pH')['quality'].mean()
# Out:
# pH
# High           5.73
# Average        5.77
# BelowAverage   5.85
# Low            5.83
# Name: quality, dtype: float64

# %% [markdown]
# it's clear that all four acidity levels has close mean quality, but the Low acidity level has the highest quality in our dataset.

# %% [markdown]
# The conclusion of the Exploratory Data Analysis (EDA) on the wine quality dataset typically includes the following key insights:
#
# 1. **Quality Distribution**: The quality ratings of the wines are mostly concentrated around the middle range (4 to 6), indicating that most wines are rated average.
#
# 2. **Influence of Alcohol**: There is a positive correlation between alcohol content and wine quality, suggesting that wines with higher alcohol levels tend to receive better quality ratings.
#
# 3. **Impact of Acidity**: Volatile acidity is negatively correlated with quality. Higher levels of volatile acidity are associated with lower quality ratings, indicating that excessive acidity can detract from the wine's quality.
#
# 4. **Other Chemical Properties**: Features such as fixed acidity and residual sugar also show varying degrees of influence on wine quality. For example, wines with balanced acidity and lower residual sugar levels tend to score higher in quality.
#
# 5. **Outlier Detection**: The analysis may have identified certain outliers in features like fixed acidity and residual sugar, which could impact the overall quality ratings.
#
# 6. **Feature Relationships**: The EDA reveals complex relationships among various features, highlighting the importance of multiple chemical properties in determining the overall quality of the wine.
#
# These insights can guide winemakers in understanding the characteristics that contribute to higher quality wines and inform future production decisions.
