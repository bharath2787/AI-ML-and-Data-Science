# %%
import numpy as np

# %%
np.repeat("red",20)
# Out:
# array(['red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red',
#        'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red', 'red',
#        'red', 'red'], dtype='<U3')
