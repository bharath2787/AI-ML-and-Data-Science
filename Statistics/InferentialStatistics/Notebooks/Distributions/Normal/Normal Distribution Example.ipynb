# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem Statement
# The mean weight of a morning breakfast cereal pack is 0.295 kg with a standard deviation of 0.025 kg. The random variable weight of the pack follows a normal distribution.
#
# a)What is the probability that the pack weighs less than 0.280 kg?
#
# b)What is the probability that the pack weighs more than 0.350 kg?
#
# c)What is the probability that the pack weighs between 0.260 kg to 0.340 kg?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mean  = .295
sigma = .025

# %% [markdown]
# ##a)What is the probability that the pack weighs less than 0.280 kg?

# %% [markdown]
# #### using z score

# %%
z = (.280 - mean)/sigma

# %%
#for problem a - Calculate the z value

z=(0.280-0.295)/0.025
z
# Out:
# -0.5999999999999983

# %%
#Use the calculated z value to calculate the probability or the area under curve to the left of this z value

stats.norm.cdf(z)
# Out:
# 0.2742531177500741

# %% [markdown]
# #### using normal distribution

# %%
#Use the orginal values to calculate the probability

stats.norm.cdf(0.280,loc=0.295,scale=0.025)

# Parameters

# x (0.280):
# This is the value at which you want to evaluate the CDF.
# In this case, you're interested in the probability that a normally distributed random variable is less than or equal to 0.280.

# loc (0.295):
# This is the mean (μ) of the normal distribution.
# It represents the center of the distribution. Here, the mean of the normal distribution is 0.295.

# scale (0.025):
# This is the standard deviation (σ) of the normal distribution.
# It measures the spread or dispersion of the distribution. A smaller standard deviation means that the values are closely clustered around the mean. In this case, the standard deviation is 0.025.
# Out:
# 0.2742531177500741

# %% [markdown]
# ###What is the probability that the pack weighs more than 0.350 kg?

# %% [markdown]
# #### using normal dist

# %%
#b) The probability (area) to the right is calculated as (1 - probability to the left)

1-stats.norm.cdf(0.350,loc=0.295,scale=0.025)
# Out:
# 0.01390344751349859

# %% [markdown]
# ####using zscore

# %%
z1 = (.350 - mean)/sigma

# %%
1-stats.norm.cdf(z1)
# Out:
# 0.01390344751349859

# %% [markdown]
# ###c)What is the probability that the pack weighs between 0.260 kg to 0.340 kg?

# %% [markdown]
# ####using normal dist

# %%
#c) The probability between points can be calculated by taking differences

stats.norm.cdf(0.340,loc=0.295,scale=0.025)-stats.norm.cdf(0.260,loc=0.295,scale=0.025)
# Out:
# 0.8833130216533032

# %% [markdown]
# #### using zscore

# %%
zlow = (.260 - mean)/sigma
zhigh = (.340 - mean)/sigma

# %%
stats.norm.cdf(zhigh) - stats.norm.cdf(zlow)
# Out:
# 0.8833130216533032

# %%
#The probability of being between 1 standard deviations of the mean

stats.norm.cdf(1)-stats.norm.cdf(-1)
# Out:
# 0.6826894921370859

# %%
#The probability of being between 2 standard deviations of the mean

stats.norm.cdf(2)-stats.norm.cdf(-2)
# Out:
# 0.9544997361036416

# %%
#The probability of being between 3 standard deviations of the mean

stats.norm.cdf(3)-stats.norm.cdf(-3)
# Out:
# 0.9973002039367398

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Given:
#
# Mean (
# 𝜇
# μ) = 10.01 mm
# Standard deviation (
# 𝜎
# σ) = 0.06 mm

# %%
mean = 10.01
sigma = .06

# %% [markdown]
# ###(a) Probability that the bolt produced will be longer than 10.2 mm

# %%
z=(10.2- mean)/sigma
z
# Out:
# 3.1666666666666585

# %%
(1-stats.norm.cdf(z))*100
# Out:
# 0.0770984784470019

# %% [markdown]
# ###(b) Probability that a bolt will be between 9.9 and 10.15 mm

# %%
z1=(9.9- mean)/sigma
z1
# Out:
# -1.833333333333324

# %%
z2=(10.15- mean)/sigma
z2
# Out:
# 2.333333333333343

# %%
(stats.norm.cdf(z2)-stats.norm.cdf(z1))*100
# Out:
# 95.6808163786537

# %% [markdown]
# ###(c) Length for which 99% of bolts produced will be less

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#here we are given prob , we need to find X

# %%
# Find the z-score for the 99th percentile
z_score_99 = stats.norm.ppf(0.99)
print(z_score_99)
# Out:
# 2.3263478740408408

# %%
L = mean+ z_score_99 * sigma

# %%
L
# Out:
# 10.149580872442451

# %% [markdown]
# ##So, 99% of bolts will be less than approximately 10.15 mm.
