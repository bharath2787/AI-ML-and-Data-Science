# %% [markdown]
# Here’s a **detailed story-based example** to set the context for inferential statistics.
#
# ---
#
# ## **Story: The New Café in Town – A Business Owner’s Dilemma**
#
# ### **The Problem**
# Imagine you are opening a new café in a busy city. You’ve spent months preparing the perfect menu, designing the interior, and hiring the best staff. Now, you have an important question:
#
# 💡 **"Will people like our new café?"**
#
# You can’t ask **everyone in the city** because there are thousands (or even millions) of potential customers. So, how do you figure out whether people will love your café before making big decisions like expanding, changing the menu, or offering discounts?
#
# This is where **inferential statistics** comes in!
#
# ---
#
# ### **Step 1: Collecting a Sample Instead of Asking Everyone**
# Since you can’t survey everyone in the city, you decide to **collect data from a small, carefully chosen group** of people who visited your café in the first month.
#
# 🔹 **Total city population:** 500,000 people
# 🔹 **Customers who visited in the first month:** 2,000 people
# 🔹 **Survey conducted on:** 300 randomly chosen customers
#
# You ask these 300 customers:
# ✅ How would you rate your experience? (1 to 5 stars)
# ✅ Would you recommend this café to others? (Yes/No)
#
# ---
#
# ### **Step 2: Using Sample Data to Make Predictions**
# After analyzing the **300 survey responses**, you find that:
# 📌 85% of customers gave 4 or 5 stars.
# 📌 90% said they would recommend the café to friends.
#
# Since this **sample represents the larger population**, you can use **inferential statistics** to make predictions about the entire city's reaction to your café!
#
# For example, you might say:
# 💡 **"We are 95% confident that between 80% and 90% of all city residents would like our café!"**
#
# ---
#
# ### **Step 3: Making Business Decisions Using Statistics**
# With this insight, you decide to:
# ✔ Expand marketing to attract more customers.
# ✔ Keep the current menu because most people liked it.
# ✔ Consider opening a second branch based on the demand.
#
# You didn’t need to **ask all 500,000 people**—just a small, well-chosen sample helped you make **data-driven decisions** for the future.
#
# ---
#
# ## **Moral of the Story: Why We Need Inferential Statistics?**
# 🔹 **We can’t always collect data from everyone** (too costly and time-consuming).
# 🔹 **A well-selected sample can represent the whole population**.
# 🔹 **Inferential statistics helps us make decisions based on data**, even with uncertainty.
