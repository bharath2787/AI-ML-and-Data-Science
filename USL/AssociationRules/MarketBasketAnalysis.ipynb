# %% [markdown]
# **Market Basket Analysis** and **Association Rules** are key concepts in data mining, often used in retail and e-commerce to understand customer purchasing behavior.
# ---
#
# ###  **Market Basket Analysis (MBA)**
#
# It’s a technique used to find **patterns or associations** between items that customers buy together.
#
# #### Example:
# If many customers who buy **bread** also buy **butter**, MBA helps you discover that pattern.
#
# So you might get a rule like:
# > **Bread → Butter**
# (If someone buys bread, they’re likely to buy butter too)
#
# ---
#
# ###  **Association Rules**
#
# These are **if-then statements** that help capture relationships between items.
#
# Each rule has 3 key metrics:
#
# 1. **Support**
#    - How frequently the items appear together in the dataset.
#    - Example: 20% of all transactions include both bread and butter.
#
# 2. **Confidence**
#    - How often the rule has been found to be true.
#    - Example: In 80% of cases where bread is bought, butter is also bought.
#
# 3. **Lift**
#    - How much more likely the two items are to be bought together compared to if they were independent.
#    - Lift > 1 means a **positive association**.
#
# ---
#
# ### 💡 Real-Life Uses
# - Product placement in stores.
# - Recommender systems ("Customers who bought this also bought...")
# - Inventory and promotion planning.
