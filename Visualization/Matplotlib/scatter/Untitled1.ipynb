# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cricket = pd.read_csv('/content/drive/MyDrive/0.Latest_DS_Course/Visualization/Data/cricketStats.csv')

# %%
cricket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     82 non-null     int64
#  1   PLAYER  82 non-null     object
#  2   Mat     82 non-null     int64
#  3   Inns    82 non-null     int64
#  4   NO      82 non-null     int64
#  5   Runs    82 non-null     int64
#  6   HS      82 non-null     object
#  7   Avg     82 non-null     float64
#  8   BF      82 non-null     int64
#  9   SR      82 non-null     float64
#  10  100     82 non-null     int64
#  11  50      82 non-null     int64
#  12  4s      82 non-null     int64
#  13  6s      82 non-null     int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 9.1+ KB

# %%
df = cricket[['PLAYER','Runs','Avg','SR','6s']]

# %%
df
# Out:
#               PLAYER  Runs    Avg      SR  6s
# 0       David Warner   692  69.20  143.86  21
# 1           KL Rahul   593  53.90  135.38  25
# 2    Quinton de Kock   529  35.26  132.91  25
# 3     Shikhar Dhawan   521  34.73  135.67  11
# 4      Andre Russell   510  56.66  204.81  52
# ..               ...   ...    ...     ...  ..
# 77      Chris Morris    32   5.33   86.48   2
# 78  Mitchell Santner    32  32.00  139.13   3
# 79     Rahul Tewatia    26  26.00  118.18   1
# 80       Umesh Yadav    25  12.50  100.00   1
# 81       Amit Mishra    21  10.50   87.50   0
#
# [82 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PLAYER  82 non-null     object
#  1   Runs    82 non-null     int64
#  2   Avg     82 non-null     float64
#  3   SR      82 non-null     float64
#  4   6s      82 non-null     int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
# plt.scatter(colx-axis, coly-axis)

# %%
df.columns
# Out:
# Index(['PLAYER', 'Runs', 'Avg', 'SR', '6s'], dtype='object')

# %%
plt.scatter(df['Avg'], df['SR'])

plt.title("AVG Vs SR")
plt.xlabel("AVG")
plt.ylabel("SR")
# Out:
# Text(0, 0.5, 'SR')

# %%
df[(df['SR']<140) & (df['Avg']>40)]
# Out:
#             PLAYER  Runs    Avg      SR  6s
# 1         KL Rahul   593  53.90  135.38  25
# 12        MS Dhoni   416  83.20  134.62  23
# 22   Manish Pandey   344  43.00  130.79   6
# 37  Marcus Stoinis   211  52.75  135.25  10
# 40   Sarfaraz Khan   180  45.00  125.87   4
# 42   Mandeep Singh   165  41.25  137.50   4

# %%
plt.scatter(df['Avg'], df['SR'], alpha=0.3)

# %%
plt.scatter(df['Avg'], df['SR'], edgecolors='r', linewidths=1, color = "y")

# %%
plt.scatter(df['Avg'], df['SR'], edgecolors='r', linewidths=1, color = "y", s=df['Runs'])

# %%
plt.scatter(df['Avg'], df['SR'], edgecolors='r', linewidths=1, color = "g", s=df['Runs'])

# %%
# plt.hist(colonXaxis)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
data.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
plt.hist(data['petal length (cm)'])
plt.title("histogram for petal length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(data['petal length (cm)'], bins=30)
plt.title("histogram for petal length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data['petal length (cm)'].min(), data['petal length (cm)'].max()
# Out:
# (1.0, 6.9)

# %%
plt.hist(data['petal length (cm)'], bins=4, rwidth=1, color='r', histtype='step')
plt.title("histogram for petal length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data['petal length (cm)'].hist()
# Out:
# <Axes: >
