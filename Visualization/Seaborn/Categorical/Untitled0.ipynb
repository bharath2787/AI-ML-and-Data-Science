# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Step 1: Create the dataset
data = {
    'Student': [f'Student{i}' for i in range(1, 21)],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female',
               'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']
}
df = pd.DataFrame(data)
print("gneder count: ",df['Gender'].value_counts())
# Out:
# gneder count:  Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
# Load example dataset
tips = sns.load_dataset('tips')

# %%
sns.barplot(data=tips, x='day', y="total_bill", estimator='max')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x='day', y="total_bill", estimator='max')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.countplot(data=tips, x="size", hue='time')
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.countplot(data=tips, x='day')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
tips[tips['day']=="Thur"].shape
# Out:
# (62, 7)

# %%
sns.catplot(data=tips, x='day', kind='count')

# %%
sns.catplot(data=tips, x='day', y="total_bill", kind='point')

# %%
sns.catplot(data=tips, x='day', y="total_bill", row = "sex", kind='point', col='size')

# %%
sns.catplot(data=tips, x='size', kind='count', col='day', row="sex")

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(data=tips, x="total_bill", y="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data=tips, x="total_bill", hue='day')
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(data=tips, y="total_bill", x='day', palette="tab10")
# Out:
# <ipython-input-21-62acec4eca8a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, y="total_bill", x='day', palette="tab10")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, y="total_bill", col='day', row="sex", palette="tab10", kind='violin')
# Out:
# <ipython-input-22-6803b3492eb3>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=tips, y="total_bill", col='day', row="sex", palette="tab10", kind='violin')

# %%
sns.kdeplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.violinplot(data=tips, y="total_bill", hue="smoker")
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.histplot(data=tips, x="total_bill", hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
# cat vs num

# %%
sns.boxplot(data=tips, x='day', y="total_bill", palette="Dark2")
# Out:
# <ipython-input-30-5a95f821c08e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x='day', y="total_bill", palette="Dark2")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.kdeplot(data=tips, x="total_bill")
plt.grid()

# %%
sns.violinplot(data=tips, y="total_bill", x="day", palette="Set1")
plt.grid()
# Out:
# <ipython-input-36-c3803eb79bdd>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=tips, y="total_bill", x="day", palette="Set1")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the flights dataset
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
