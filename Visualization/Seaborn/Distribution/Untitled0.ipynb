# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load example dataset
tips = sns.load_dataset("tips")

# %%
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill'].min(),tips['total_bill'].max()
# Out:
# (3.07, 50.81)

# %%
sns.displot(data=tips, x='total_bill')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(data=tips, x='total_bill', hue='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# facet plot

# %%
sns.displot(data=tips, x='total_bill', col='day', row='smoker')

# %%
sns.kdeplot(data=tips, x="total_bill", hue='sex', fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips, x="total_bill", col='smoker', row='day', kind='kde')

# %%
sns.displot(data=tips, x="total_bill", col='smoker', row='day', kde=True)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(data=tips, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.stripplot(data=tips, x="day", y="total_bill", hue='size', palette="Set1")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.catplot(data=tips, x="day", y="total_bill", row="sex", col="day", kind='strip')

# %%
sns.swarmplot(data=tips, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Step 1: Create the dataset
data = {
    'Student': [f'Student{i}' for i in range(1, 21)],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female',
               'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']
}
df = pd.DataFrame(data)
print("gneder count: ",df['Gender'].value_counts())
# Out:
# gneder count:  Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  20 non-null     object
#  1   Gender   20 non-null     object
# dtypes: object(2)
# memory usage: 452.0+ bytes

# %%
sns.countplot(data=df, x="Gender")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
sns.barplot(data=tips, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
tips[tips['day']=="Thur"]['total_bill'].min()
# Out:
# 7.51

# %%
sns.barplot(data=tips, x="day", y="total_bill", estimator='min')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x="day", y="total_bill", estimator='mean')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, y="day", x="total_bill", estimator='min', hue='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.catplot(data=tips, x='smoker', kind='count')

# %%
sns.catplot(data=tips, x='smoker',y='total_bill', kind='bar',row='sex', col='day')

# %%
sns.catplot(data=tips, x="smoker", kind='count', col="sex", row='size')
