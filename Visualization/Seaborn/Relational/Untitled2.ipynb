# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load example dataset
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
tips['total_bill'].min(), tips['total_bill'].max()
# Out:
# (3.07, 50.81)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.histplot(data=tips, x="total_bill", hue="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill", hue="day")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x="total_bill", col="day", row='time', hue='smoker', kind='kde')
# Out:
# <ipython-input-14-36edc7525d14>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data=tips, x="total_bill", col="day", row='time', hue='smoker', kind='kde')

# %%
sns.kdeplot(data=tips, x="total_bill", hue="sex")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=tips, x="total_bill", col="day", kind='kde')

# %%
sns.displot(data=tips, x="total_bill", hue="sex",col='day', kde=True)

# %%
# Step 1: Create the dataset
data = {
    'Student': [f'Student{i}' for i in range(1, 21)],
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female',
               'Female', 'Male', 'Male', 'Female', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male']
}
df = pd.DataFrame(data)
print("gneder count: ",df['Gender'].value_counts())
# Out:
# gneder count:  Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
df
# Out:
#       Student  Gender
# 0    Student1    Male
# 1    Student2  Female
# 2    Student3  Female
# 3    Student4    Male
# 4    Student5  Female
# 5    Student6    Male
# 6    Student7  Female
# 7    Student8    Male
# 8    Student9    Male
# 9   Student10  Female
# 10  Student11  Female
# 11  Student12    Male
# 12  Student13    Male
# 13  Student14  Female
# 14  Student15  Female
# 15  Student16    Male
# 16  Student17  Female
# 17  Student18    Male
# 18  Student19  Female
# 19  Student20    Male

# %%
plt.figure(figsize=(3, 3))

sns.countplot(data=df, x="Gender", palette="Dark2")
# Out:
# <ipython-input-38-b9a922a283b8>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="Gender", palette="Dark2")
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
df.groupby("Gender").size()
# Out:
# Gender
# Female    10
# Male      10
# dtype: int64

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(data=tips, x='day', y='total_bill' )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='day', y='total_bill' , estimator= "max" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='day', y='total_bill' , estimator= "min" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='day', y='total_bill' , estimator= "mean" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips, y='day', x='total_bill' , hue="sex" )
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(data=tips, x="smoker")
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.pointplot(data=tips, x='day', y='total_bill' , estimator= "mean" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x='day', y='total_bill' , estimator= "max" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.pointplot(data=tips, x='day', y='total_bill' , estimator= "min" )
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x='day', y='total_bill' , estimator= "mean" , kind='bar')

# %%
sns.catplot(data=tips, x='day', y='total_bill' , estimator= "mean" , kind='strip')

# %%
sns.stripplot(data=tips, x="day", y="total_bill")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.stripplot(data=tips, x="day", y="total_bill", jitter=False)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips['day'].value_counts(normalize=True)*100
# Out:
# day
# Sat     35.655738
# Sun     31.147541
# Thur    25.409836
# Fri      7.786885
# Name: proportion, dtype: float64

# %%
sns.swarmplot(data=tips, x="day", y="total_bill", hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(data=tips, x="day", y="total_bill", col="day", row="time", hue="sex", kind="point")

# %%
sns.boxplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill'>

# %%
# for univariate: take a single continuous value on the XAxis
# for bivariate, one categorical xaxis and continuous of y-axis

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(data=tips, y="day", x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
tips['total_bill'].mean()
# Out:
# 19.78594262295082
